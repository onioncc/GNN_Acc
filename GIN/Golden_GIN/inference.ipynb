# %%
import torch
from torch_geometric.data import DataLoader
import torch.optim as optim
import torch.nn.functional as F
from gnn import GNN
from sklearn.metrics import roc_auc_score

from tqdm import tqdm
import argparse
import time
import numpy as np

### importing OGB
from ogb.graphproppred import PygGraphPropPredDataset, Evaluator

def eval_rocauc(y_true, y_pred):
    rocauc_list = []

    for i in range(y_true.shape[1]):
        #AUC is only defined when there is at least one positive data.
        if np.sum(y_true[:,i] == 1) > 0 and np.sum(y_true[:,i] == 0) > 0:
            # ignore nan values
            is_labeled = y_true[:,i] == y_true[:,i]
            rocauc_list.append(roc_auc_score(y_true[is_labeled,i], y_pred[is_labeled,i]))
        print('y_true', y_true[:, i])
        print('y_pred', y_pred[:, i])
    # print(sum(rocauc_list), len(rocauc_list))
    # print(rocauc_list)

    # if len(rocauc_list) == 0:
    #     raise RuntimeError('No positively labeled data available. Cannot compute ROC-AUC.')
    # return {'rocauc': sum(rocauc_list)/len(rocauc_list)}


def eval(model, device, loader, evaluator):
    model.eval()
    y_true = []
    y_pred = []
    for step, batch in enumerate(loader):
        batch = batch.to(device)
        print(batch)
        with torch.no_grad():
            pred = model(batch)
        y_true.append(batch.y.view(pred.shape).detach().cpu())
        y_pred.append(pred.detach().cpu())

    y_true = torch.cat(y_true, dim = 0).numpy()
    y_pred = torch.cat(y_pred, dim = 0).numpy()
    
    eval_rocauc(y_true, y_pred)
    return y_true, y_pred


device = torch.device("cpu")
dataset = PygGraphPropPredDataset(name = 'ogbg-molhiv')
split_idx = dataset.get_idx_split()
evaluator = Evaluator('ogbg-molhiv')
test_loader = DataLoader(dataset[split_idx["test"]], batch_size=1, shuffle=False, num_workers = 1)

model = torch.load('gin_ep1_dim100.pt')
#model = GNN(gnn_type = 'gin', num_tasks = 1, num_layer = 5, emb_dim = 300, drop_ratio = 0.5, virtual_node = False).to(device)
print('Evaluating...')
ytrue, ypred = eval(model, device, test_loader, evaluator)


graph_id = 1
import json
all_result = {}
f_txt = open('golden_output_dim100.txt', 'w+')
for yt, yp in zip(ytrue, ypred):
    print(yt[0], yp[0])
    key = 'g' + str(graph_id)
    all_result[key] = {}
    all_result[key]['true'] = float(yt[0])
    all_result[key]['predict'] = float(yp[0])
    graph_id += 1
    f_txt.write(key + ': ' + str(yp[0]) + '\n')
f_txt.close()

f_json = open('all_results_dim100.json', 'w+')
json.dump(all_result, f_json)
f_json.close()
# Out:
# WARNING:root:The OGB package is out of date. Your version is 1.2.6, while the latest version is 1.3.1.
# Evaluating...
# Batch(batch=[19], edge_attr=[40, 3], edge_index=[2, 40], x=[19, 9], y=[1, 1])
# Batch(batch=[39], edge_attr=[88, 3], edge_index=[2, 88], x=[39, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[48, 3], edge_index=[2, 48], x=[21, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[38, 3], edge_index=[2, 38], x=[18, 9], y=[1, 1])
# Batch(batch=[23], edge_attr=[50, 3], edge_index=[2, 50], x=[23, 9], y=[1, 1])
# Batch(batch=[29], edge_attr=[64, 3], edge_index=[2, 64], x=[29, 9], y=[1, 1])
# Batch(batch=[37], edge_attr=[76, 3], edge_index=[2, 76], x=[37, 9], y=[1, 1])
# Batch(batch=[23], edge_attr=[50, 3], edge_index=[2, 50], x=[23, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[38, 3], edge_index=[2, 38], x=[18, 9], y=[1, 1])
# Batch(batch=[13], edge_attr=[28, 3], edge_index=[2, 28], x=[13, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[54, 3], edge_index=[2, 54], x=[26, 9], y=[1, 1])
# Batch(batch=[9], edge_attr=[20, 3], edge_index=[2, 20], x=[9, 9], y=[1, 1])
# Batch(batch=[9], edge_attr=[20, 3], edge_index=[2, 20], x=[9, 9], y=[1, 1])
# Batch(batch=[8], edge_attr=[18, 3], edge_index=[2, 18], x=[8, 9], y=[1, 1])
# Batch(batch=[38], edge_attr=[82, 3], edge_index=[2, 82], x=[38, 9], y=[1, 1])
# Batch(batch=[32], edge_attr=[70, 3], edge_index=[2, 70], x=[32, 9], y=[1, 1])
# Batch(batch=[15], edge_attr=[32, 3], edge_index=[2, 32], x=[15, 9], y=[1, 1])
# Batch(batch=[39], edge_attr=[84, 3], edge_index=[2, 84], x=[39, 9], y=[1, 1])
# Batch(batch=[15], edge_attr=[30, 3], edge_index=[2, 30], x=[15, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[58, 3], edge_index=[2, 58], x=[26, 9], y=[1, 1])
# Batch(batch=[44], edge_attr=[94, 3], edge_index=[2, 94], x=[44, 9], y=[1, 1])
# Batch(batch=[13], edge_attr=[28, 3], edge_index=[2, 28], x=[13, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[44, 3], edge_index=[2, 44], x=[21, 9], y=[1, 1])
# Batch(batch=[14], edge_attr=[30, 3], edge_index=[2, 30], x=[14, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[52, 3], edge_index=[2, 52], x=[26, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[36, 3], edge_index=[2, 36], x=[16, 9], y=[1, 1])
# Batch(batch=[12], edge_attr=[24, 3], edge_index=[2, 24], x=[12, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[32, 3], edge_index=[2, 32], x=[16, 9], y=[1, 1])
# Batch(batch=[31], edge_attr=[66, 3], edge_index=[2, 66], x=[31, 9], y=[1, 1])
# Batch(batch=[19], edge_attr=[42, 3], edge_index=[2, 42], x=[19, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[50, 3], edge_index=[2, 50], x=[21, 9], y=[1, 1])
# Batch(batch=[27], edge_attr=[60, 3], edge_index=[2, 60], x=[27, 9], y=[1, 1])
# Batch(batch=[90], edge_attr=[192, 3], edge_index=[2, 192], x=[90, 9], y=[1, 1])
# Batch(batch=[34], edge_attr=[74, 3], edge_index=[2, 74], x=[34, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[38, 3], edge_index=[2, 38], x=[18, 9], y=[1, 1])
# Batch(batch=[11], edge_attr=[24, 3], edge_index=[2, 24], x=[11, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[48, 3], edge_index=[2, 48], x=[21, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[58, 3], edge_index=[2, 58], x=[26, 9], y=[1, 1])
# Batch(batch=[33], edge_attr=[76, 3], edge_index=[2, 76], x=[33, 9], y=[1, 1])
# Batch(batch=[43], edge_attr=[94, 3], edge_index=[2, 94], x=[43, 9], y=[1, 1])
# Batch(batch=[46], edge_attr=[92, 3], edge_index=[2, 92], x=[46, 9], y=[1, 1])
# Batch(batch=[44], edge_attr=[100, 3], edge_index=[2, 100], x=[44, 9], y=[1, 1])
# Batch(batch=[45], edge_attr=[102, 3], edge_index=[2, 102], x=[45, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[38, 3], edge_index=[2, 38], x=[18, 9], y=[1, 1])
# Batch(batch=[17], edge_attr=[38, 3], edge_index=[2, 38], x=[17, 9], y=[1, 1])
# Batch(batch=[34], edge_attr=[72, 3], edge_index=[2, 72], x=[34, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[38, 3], edge_index=[2, 38], x=[18, 9], y=[1, 1])
# Batch(batch=[12], edge_attr=[26, 3], edge_index=[2, 26], x=[12, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[52, 3], edge_index=[2, 52], x=[21, 9], y=[1, 1])
# Batch(batch=[14], edge_attr=[30, 3], edge_index=[2, 30], x=[14, 9], y=[1, 1])
# Batch(batch=[17], edge_attr=[40, 3], edge_index=[2, 40], x=[17, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[48, 3], edge_index=[2, 48], x=[21, 9], y=[1, 1])
# Batch(batch=[19], edge_attr=[42, 3], edge_index=[2, 42], x=[19, 9], y=[1, 1])
# Batch(batch=[15], edge_attr=[30, 3], edge_index=[2, 30], x=[15, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[48, 3], edge_index=[2, 48], x=[22, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[50, 3], edge_index=[2, 50], x=[22, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[48, 3], edge_index=[2, 48], x=[22, 9], y=[1, 1])
# Batch(batch=[12], edge_attr=[28, 3], edge_index=[2, 28], x=[12, 9], y=[1, 1])
# Batch(batch=[23], edge_attr=[48, 3], edge_index=[2, 48], x=[23, 9], y=[1, 1])
# Batch(batch=[40], edge_attr=[86, 3], edge_index=[2, 86], x=[40, 9], y=[1, 1])
# Batch(batch=[59], edge_attr=[118, 3], edge_index=[2, 118], x=[59, 9], y=[1, 1])
# Batch(batch=[13], edge_attr=[28, 3], edge_index=[2, 28], x=[13, 9], y=[1, 1])
# Batch(batch=[7], edge_attr=[14, 3], edge_index=[2, 14], x=[7, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[34, 3], edge_index=[2, 34], x=[16, 9], y=[1, 1])
# Batch(batch=[29], edge_attr=[64, 3], edge_index=[2, 64], x=[29, 9], y=[1, 1])
# Batch(batch=[9], edge_attr=[18, 3], edge_index=[2, 18], x=[9, 9], y=[1, 1])
# Batch(batch=[13], edge_attr=[28, 3], edge_index=[2, 28], x=[13, 9], y=[1, 1])
# Batch(batch=[27], edge_attr=[60, 3], edge_index=[2, 60], x=[27, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[36, 3], edge_index=[2, 36], x=[16, 9], y=[1, 1])
# Batch(batch=[20], edge_attr=[42, 3], edge_index=[2, 42], x=[20, 9], y=[1, 1])
# Batch(batch=[13], edge_attr=[28, 3], edge_index=[2, 28], x=[13, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[48, 3], edge_index=[2, 48], x=[22, 9], y=[1, 1])
# Batch(batch=[24], edge_attr=[56, 3], edge_index=[2, 56], x=[24, 9], y=[1, 1])
# Batch(batch=[43], edge_attr=[96, 3], edge_index=[2, 96], x=[43, 9], y=[1, 1])
# Batch(batch=[36], edge_attr=[76, 3], edge_index=[2, 76], x=[36, 9], y=[1, 1])
# Batch(batch=[31], edge_attr=[72, 3], edge_index=[2, 72], x=[31, 9], y=[1, 1])
# Batch(batch=[29], edge_attr=[64, 3], edge_index=[2, 64], x=[29, 9], y=[1, 1])
# Batch(batch=[36], edge_attr=[88, 3], edge_index=[2, 88], x=[36, 9], y=[1, 1])
# Batch(batch=[41], edge_attr=[90, 3], edge_index=[2, 90], x=[41, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[54, 3], edge_index=[2, 54], x=[26, 9], y=[1, 1])
# Batch(batch=[37], edge_attr=[76, 3], edge_index=[2, 76], x=[37, 9], y=[1, 1])
# Batch(batch=[19], edge_attr=[44, 3], edge_index=[2, 44], x=[19, 9], y=[1, 1])
# Batch(batch=[10], edge_attr=[22, 3], edge_index=[2, 22], x=[10, 9], y=[1, 1])
# Batch(batch=[27], edge_attr=[60, 3], edge_index=[2, 60], x=[27, 9], y=[1, 1])
# Batch(batch=[19], edge_attr=[40, 3], edge_index=[2, 40], x=[19, 9], y=[1, 1])
# Batch(batch=[17], edge_attr=[38, 3], edge_index=[2, 38], x=[17, 9], y=[1, 1])
# Batch(batch=[13], edge_attr=[26, 3], edge_index=[2, 26], x=[13, 9], y=[1, 1])
# Batch(batch=[25], edge_attr=[54, 3], edge_index=[2, 54], x=[25, 9], y=[1, 1])
# Batch(batch=[13], edge_attr=[28, 3], edge_index=[2, 28], x=[13, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[40, 3], edge_index=[2, 40], x=[18, 9], y=[1, 1])
# Batch(batch=[36], edge_attr=[78, 3], edge_index=[2, 78], x=[36, 9], y=[1, 1])
# Batch(batch=[11], edge_attr=[26, 3], edge_index=[2, 26], x=[11, 9], y=[1, 1])
# Batch(batch=[25], edge_attr=[50, 3], edge_index=[2, 50], x=[25, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[34, 3], edge_index=[2, 34], x=[16, 9], y=[1, 1])
# Batch(batch=[28], edge_attr=[62, 3], edge_index=[2, 62], x=[28, 9], y=[1, 1])
# Batch(batch=[7], edge_attr=[14, 3], edge_index=[2, 14], x=[7, 9], y=[1, 1])
# Batch(batch=[6], edge_attr=[12, 3], edge_index=[2, 12], x=[6, 9], y=[1, 1])
# Batch(batch=[33], edge_attr=[76, 3], edge_index=[2, 76], x=[33, 9], y=[1, 1])
# Batch(batch=[48], edge_attr=[104, 3], edge_index=[2, 104], x=[48, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[50, 3], edge_index=[2, 50], x=[22, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[50, 3], edge_index=[2, 50], x=[21, 9], y=[1, 1])
# Batch(batch=[31], edge_attr=[72, 3], edge_index=[2, 72], x=[31, 9], y=[1, 1])
# Batch(batch=[49], edge_attr=[110, 3], edge_index=[2, 110], x=[49, 9], y=[1, 1])
# Batch(batch=[11], edge_attr=[24, 3], edge_index=[2, 24], x=[11, 9], y=[1, 1])
# Batch(batch=[30], edge_attr=[66, 3], edge_index=[2, 66], x=[30, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[36, 3], edge_index=[2, 36], x=[16, 9], y=[1, 1])
# Batch(batch=[25], edge_attr=[60, 3], edge_index=[2, 60], x=[25, 9], y=[1, 1])
# Batch(batch=[39], edge_attr=[84, 3], edge_index=[2, 84], x=[39, 9], y=[1, 1])
# Batch(batch=[49], edge_attr=[110, 3], edge_index=[2, 110], x=[49, 9], y=[1, 1])
# Batch(batch=[11], edge_attr=[24, 3], edge_index=[2, 24], x=[11, 9], y=[1, 1])
# Batch(batch=[12], edge_attr=[26, 3], edge_index=[2, 26], x=[12, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[32, 3], edge_index=[2, 32], x=[16, 9], y=[1, 1])
# Batch(batch=[27], edge_attr=[60, 3], edge_index=[2, 60], x=[27, 9], y=[1, 1])
# Batch(batch=[28], edge_attr=[62, 3], edge_index=[2, 62], x=[28, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[50, 3], edge_index=[2, 50], x=[22, 9], y=[1, 1])
# Batch(batch=[19], edge_attr=[42, 3], edge_index=[2, 42], x=[19, 9], y=[1, 1])
# Batch(batch=[10], edge_attr=[20, 3], edge_index=[2, 20], x=[10, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[46, 3], edge_index=[2, 46], x=[22, 9], y=[1, 1])
# Batch(batch=[27], edge_attr=[60, 3], edge_index=[2, 60], x=[27, 9], y=[1, 1])
# Batch(batch=[31], edge_attr=[74, 3], edge_index=[2, 74], x=[31, 9], y=[1, 1])
# Batch(batch=[43], edge_attr=[94, 3], edge_index=[2, 94], x=[43, 9], y=[1, 1])
# Batch(batch=[52], edge_attr=[114, 3], edge_index=[2, 114], x=[52, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[48, 3], edge_index=[2, 48], x=[21, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[40, 3], edge_index=[2, 40], x=[18, 9], y=[1, 1])
# Batch(batch=[12], edge_attr=[26, 3], edge_index=[2, 26], x=[12, 9], y=[1, 1])
# Batch(batch=[27], edge_attr=[58, 3], edge_index=[2, 58], x=[27, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[58, 3], edge_index=[2, 58], x=[26, 9], y=[1, 1])
# Batch(batch=[15], edge_attr=[36, 3], edge_index=[2, 36], x=[15, 9], y=[1, 1])
# Batch(batch=[31], edge_attr=[70, 3], edge_index=[2, 70], x=[31, 9], y=[1, 1])
# Batch(batch=[37], edge_attr=[80, 3], edge_index=[2, 80], x=[37, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[36, 3], edge_index=[2, 36], x=[16, 9], y=[1, 1])
# Batch(batch=[23], edge_attr=[52, 3], edge_index=[2, 52], x=[23, 9], y=[1, 1])
# Batch(batch=[44], edge_attr=[100, 3], edge_index=[2, 100], x=[44, 9], y=[1, 1])
# Batch(batch=[14], edge_attr=[32, 3], edge_index=[2, 32], x=[14, 9], y=[1, 1])
# Batch(batch=[30], edge_attr=[64, 3], edge_index=[2, 64], x=[30, 9], y=[1, 1])
# Batch(batch=[11], edge_attr=[24, 3], edge_index=[2, 24], x=[11, 9], y=[1, 1])
# Batch(batch=[20], edge_attr=[44, 3], edge_index=[2, 44], x=[20, 9], y=[1, 1])
# Batch(batch=[12], edge_attr=[26, 3], edge_index=[2, 26], x=[12, 9], y=[1, 1])
# Batch(batch=[19], edge_attr=[42, 3], edge_index=[2, 42], x=[19, 9], y=[1, 1])
# Batch(batch=[35], edge_attr=[80, 3], edge_index=[2, 80], x=[35, 9], y=[1, 1])
# Batch(batch=[58], edge_attr=[126, 3], edge_index=[2, 126], x=[58, 9], y=[1, 1])
# Batch(batch=[30], edge_attr=[64, 3], edge_index=[2, 64], x=[30, 9], y=[1, 1])
# Batch(batch=[20], edge_attr=[44, 3], edge_index=[2, 44], x=[20, 9], y=[1, 1])
# Batch(batch=[14], edge_attr=[34, 3], edge_index=[2, 34], x=[14, 9], y=[1, 1])
# Batch(batch=[50], edge_attr=[110, 3], edge_index=[2, 110], x=[50, 9], y=[1, 1])
# Batch(batch=[9], edge_attr=[24, 3], edge_index=[2, 24], x=[9, 9], y=[1, 1])
# Batch(batch=[25], edge_attr=[54, 3], edge_index=[2, 54], x=[25, 9], y=[1, 1])
# Batch(batch=[11], edge_attr=[26, 3], edge_index=[2, 26], x=[11, 9], y=[1, 1])
# Batch(batch=[38], edge_attr=[82, 3], edge_index=[2, 82], x=[38, 9], y=[1, 1])
# Batch(batch=[28], edge_attr=[60, 3], edge_index=[2, 60], x=[28, 9], y=[1, 1])
# Batch(batch=[23], edge_attr=[48, 3], edge_index=[2, 48], x=[23, 9], y=[1, 1])
# Batch(batch=[14], edge_attr=[30, 3], edge_index=[2, 30], x=[14, 9], y=[1, 1])
# Batch(batch=[12], edge_attr=[26, 3], edge_index=[2, 26], x=[12, 9], y=[1, 1])
# Batch(batch=[9], edge_attr=[20, 3], edge_index=[2, 20], x=[9, 9], y=[1, 1])
# Batch(batch=[31], edge_attr=[72, 3], edge_index=[2, 72], x=[31, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[46, 3], edge_index=[2, 46], x=[21, 9], y=[1, 1])
# Batch(batch=[29], edge_attr=[64, 3], edge_index=[2, 64], x=[29, 9], y=[1, 1])
# Batch(batch=[23], edge_attr=[50, 3], edge_index=[2, 50], x=[23, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[40, 3], edge_index=[2, 40], x=[18, 9], y=[1, 1])
# Batch(batch=[14], edge_attr=[30, 3], edge_index=[2, 30], x=[14, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[36, 3], edge_index=[2, 36], x=[16, 9], y=[1, 1])
# Batch(batch=[23], edge_attr=[50, 3], edge_index=[2, 50], x=[23, 9], y=[1, 1])
# Batch(batch=[25], edge_attr=[54, 3], edge_index=[2, 54], x=[25, 9], y=[1, 1])
# Batch(batch=[17], edge_attr=[38, 3], edge_index=[2, 38], x=[17, 9], y=[1, 1])
# Batch(batch=[24], edge_attr=[52, 3], edge_index=[2, 52], x=[24, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[58, 3], edge_index=[2, 58], x=[26, 9], y=[1, 1])
# Batch(batch=[6], edge_attr=[12, 3], edge_index=[2, 12], x=[6, 9], y=[1, 1])
# Batch(batch=[20], edge_attr=[42, 3], edge_index=[2, 42], x=[20, 9], y=[1, 1])
# Batch(batch=[30], edge_attr=[66, 3], edge_index=[2, 66], x=[30, 9], y=[1, 1])
# Batch(batch=[35], edge_attr=[74, 3], edge_index=[2, 74], x=[35, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[46, 3], edge_index=[2, 46], x=[21, 9], y=[1, 1])
# Batch(batch=[33], edge_attr=[72, 3], edge_index=[2, 72], x=[33, 9], y=[1, 1])
# Batch(batch=[34], edge_attr=[74, 3], edge_index=[2, 74], x=[34, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[48, 3], edge_index=[2, 48], x=[22, 9], y=[1, 1])
# Batch(batch=[40], edge_attr=[84, 3], edge_index=[2, 84], x=[40, 9], y=[1, 1])
# Batch(batch=[12], edge_attr=[24, 3], edge_index=[2, 24], x=[12, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[34, 3], edge_index=[2, 34], x=[16, 9], y=[1, 1])
# Batch(batch=[23], edge_attr=[52, 3], edge_index=[2, 52], x=[23, 9], y=[1, 1])
# Batch(batch=[30], edge_attr=[66, 3], edge_index=[2, 66], x=[30, 9], y=[1, 1])
# Batch(batch=[33], edge_attr=[72, 3], edge_index=[2, 72], x=[33, 9], y=[1, 1])
# Batch(batch=[15], edge_attr=[30, 3], edge_index=[2, 30], x=[15, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[36, 3], edge_index=[2, 36], x=[16, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[44, 3], edge_index=[2, 44], x=[21, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[46, 3], edge_index=[2, 46], x=[22, 9], y=[1, 1])
# Batch(batch=[34], edge_attr=[74, 3], edge_index=[2, 74], x=[34, 9], y=[1, 1])
# Batch(batch=[37], edge_attr=[82, 3], edge_index=[2, 82], x=[37, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[58, 3], edge_index=[2, 58], x=[26, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[50, 3], edge_index=[2, 50], x=[22, 9], y=[1, 1])
# Batch(batch=[33], edge_attr=[76, 3], edge_index=[2, 76], x=[33, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[32, 3], edge_index=[2, 32], x=[16, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[60, 3], edge_index=[2, 60], x=[26, 9], y=[1, 1])
# Batch(batch=[24], edge_attr=[58, 3], edge_index=[2, 58], x=[24, 9], y=[1, 1])
# Batch(batch=[36], edge_attr=[84, 3], edge_index=[2, 84], x=[36, 9], y=[1, 1])
# Batch(batch=[28], edge_attr=[66, 3], edge_index=[2, 66], x=[28, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[62, 3], edge_index=[2, 62], x=[26, 9], y=[1, 1])
# Batch(batch=[41], edge_attr=[104, 3], edge_index=[2, 104], x=[41, 9], y=[1, 1])
# Batch(batch=[40], edge_attr=[96, 3], edge_index=[2, 96], x=[40, 9], y=[1, 1])
# Batch(batch=[30], edge_attr=[68, 3], edge_index=[2, 68], x=[30, 9], y=[1, 1])
# Batch(batch=[23], edge_attr=[52, 3], edge_index=[2, 52], x=[23, 9], y=[1, 1])
# Batch(batch=[43], edge_attr=[100, 3], edge_index=[2, 100], x=[43, 9], y=[1, 1])
# Batch(batch=[14], edge_attr=[30, 3], edge_index=[2, 30], x=[14, 9], y=[1, 1])
# Batch(batch=[32], edge_attr=[66, 3], edge_index=[2, 66], x=[32, 9], y=[1, 1])
# Batch(batch=[23], edge_attr=[48, 3], edge_index=[2, 48], x=[23, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[36, 3], edge_index=[2, 36], x=[16, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[40, 3], edge_index=[2, 40], x=[18, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[48, 3], edge_index=[2, 48], x=[21, 9], y=[1, 1])
# Batch(batch=[20], edge_attr=[46, 3], edge_index=[2, 46], x=[20, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[50, 3], edge_index=[2, 50], x=[22, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[58, 3], edge_index=[2, 58], x=[26, 9], y=[1, 1])
# Batch(batch=[17], edge_attr=[36, 3], edge_index=[2, 36], x=[17, 9], y=[1, 1])
# Batch(batch=[20], edge_attr=[42, 3], edge_index=[2, 42], x=[20, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[48, 3], edge_index=[2, 48], x=[22, 9], y=[1, 1])
# Batch(batch=[19], edge_attr=[42, 3], edge_index=[2, 42], x=[19, 9], y=[1, 1])
# Batch(batch=[51], edge_attr=[112, 3], edge_index=[2, 112], x=[51, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[46, 3], edge_index=[2, 46], x=[21, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[34, 3], edge_index=[2, 34], x=[16, 9], y=[1, 1])
# Batch(batch=[25], edge_attr=[54, 3], edge_index=[2, 54], x=[25, 9], y=[1, 1])
# Batch(batch=[25], edge_attr=[54, 3], edge_index=[2, 54], x=[25, 9], y=[1, 1])
# Batch(batch=[23], edge_attr=[50, 3], edge_index=[2, 50], x=[23, 9], y=[1, 1])
# Batch(batch=[24], edge_attr=[54, 3], edge_index=[2, 54], x=[24, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[48, 3], edge_index=[2, 48], x=[22, 9], y=[1, 1])
# Batch(batch=[23], edge_attr=[48, 3], edge_index=[2, 48], x=[23, 9], y=[1, 1])
# Batch(batch=[25], edge_attr=[56, 3], edge_index=[2, 56], x=[25, 9], y=[1, 1])
# Batch(batch=[39], edge_attr=[92, 3], edge_index=[2, 92], x=[39, 9], y=[1, 1])
# Batch(batch=[59], edge_attr=[130, 3], edge_index=[2, 130], x=[59, 9], y=[1, 1])
# Batch(batch=[59], edge_attr=[132, 3], edge_index=[2, 132], x=[59, 9], y=[1, 1])
# Batch(batch=[41], edge_attr=[88, 3], edge_index=[2, 88], x=[41, 9], y=[1, 1])
# Batch(batch=[14], edge_attr=[30, 3], edge_index=[2, 30], x=[14, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[40, 3], edge_index=[2, 40], x=[18, 9], y=[1, 1])
# Batch(batch=[17], edge_attr=[36, 3], edge_index=[2, 36], x=[17, 9], y=[1, 1])
# Batch(batch=[20], edge_attr=[42, 3], edge_index=[2, 42], x=[20, 9], y=[1, 1])
# Batch(batch=[25], edge_attr=[52, 3], edge_index=[2, 52], x=[25, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[40, 3], edge_index=[2, 40], x=[18, 9], y=[1, 1])
# Batch(batch=[28], edge_attr=[64, 3], edge_index=[2, 64], x=[28, 9], y=[1, 1])
# Batch(batch=[32], edge_attr=[66, 3], edge_index=[2, 66], x=[32, 9], y=[1, 1])
# Batch(batch=[15], edge_attr=[32, 3], edge_index=[2, 32], x=[15, 9], y=[1, 1])
# Batch(batch=[15], edge_attr=[32, 3], edge_index=[2, 32], x=[15, 9], y=[1, 1])
# Batch(batch=[38], edge_attr=[86, 3], edge_index=[2, 86], x=[38, 9], y=[1, 1])
# Batch(batch=[25], edge_attr=[54, 3], edge_index=[2, 54], x=[25, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[38, 3], edge_index=[2, 38], x=[18, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[50, 3], edge_index=[2, 50], x=[22, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[60, 3], edge_index=[2, 60], x=[26, 9], y=[1, 1])
# Batch(batch=[19], edge_attr=[40, 3], edge_index=[2, 40], x=[19, 9], y=[1, 1])
# Batch(batch=[30], edge_attr=[66, 3], edge_index=[2, 66], x=[30, 9], y=[1, 1])
# Batch(batch=[11], edge_attr=[22, 3], edge_index=[2, 22], x=[11, 9], y=[1, 1])
# Batch(batch=[28], edge_attr=[64, 3], edge_index=[2, 64], x=[28, 9], y=[1, 1])
# Batch(batch=[27], edge_attr=[60, 3], edge_index=[2, 60], x=[27, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[50, 3], edge_index=[2, 50], x=[22, 9], y=[1, 1])
# Batch(batch=[24], edge_attr=[52, 3], edge_index=[2, 52], x=[24, 9], y=[1, 1])
# Batch(batch=[28], edge_attr=[64, 3], edge_index=[2, 64], x=[28, 9], y=[1, 1])
# Batch(batch=[24], edge_attr=[54, 3], edge_index=[2, 54], x=[24, 9], y=[1, 1])
# Batch(batch=[30], edge_attr=[62, 3], edge_index=[2, 62], x=[30, 9], y=[1, 1])
# Batch(batch=[24], edge_attr=[52, 3], edge_index=[2, 52], x=[24, 9], y=[1, 1])
# Batch(batch=[25], edge_attr=[54, 3], edge_index=[2, 54], x=[25, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[50, 3], edge_index=[2, 50], x=[22, 9], y=[1, 1])
# Batch(batch=[32], edge_attr=[72, 3], edge_index=[2, 72], x=[32, 9], y=[1, 1])
# Batch(batch=[14], edge_attr=[28, 3], edge_index=[2, 28], x=[14, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[34, 3], edge_index=[2, 34], x=[18, 9], y=[1, 1])
# Batch(batch=[33], edge_attr=[72, 3], edge_index=[2, 72], x=[33, 9], y=[1, 1])
# Batch(batch=[54], edge_attr=[118, 3], edge_index=[2, 118], x=[54, 9], y=[1, 1])
# Batch(batch=[24], edge_attr=[50, 3], edge_index=[2, 50], x=[24, 9], y=[1, 1])
# Batch(batch=[19], edge_attr=[44, 3], edge_index=[2, 44], x=[19, 9], y=[1, 1])
# Batch(batch=[32], edge_attr=[68, 3], edge_index=[2, 68], x=[32, 9], y=[1, 1])
# Batch(batch=[42], edge_attr=[86, 3], edge_index=[2, 86], x=[42, 9], y=[1, 1])
# Batch(batch=[33], edge_attr=[74, 3], edge_index=[2, 74], x=[33, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[38, 3], edge_index=[2, 38], x=[18, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[42, 3], edge_index=[2, 42], x=[18, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[36, 3], edge_index=[2, 36], x=[16, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[48, 3], edge_index=[2, 48], x=[22, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[50, 3], edge_index=[2, 50], x=[22, 9], y=[1, 1])
# Batch(batch=[32], edge_attr=[66, 3], edge_index=[2, 66], x=[32, 9], y=[1, 1])
# Batch(batch=[15], edge_attr=[32, 3], edge_index=[2, 32], x=[15, 9], y=[1, 1])
# Batch(batch=[15], edge_attr=[32, 3], edge_index=[2, 32], x=[15, 9], y=[1, 1])
# Batch(batch=[25], edge_attr=[52, 3], edge_index=[2, 52], x=[25, 9], y=[1, 1])
# Batch(batch=[23], edge_attr=[52, 3], edge_index=[2, 52], x=[23, 9], y=[1, 1])
# Batch(batch=[14], edge_attr=[30, 3], edge_index=[2, 30], x=[14, 9], y=[1, 1])
# Batch(batch=[12], edge_attr=[26, 3], edge_index=[2, 26], x=[12, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[34, 3], edge_index=[2, 34], x=[16, 9], y=[1, 1])
# Batch(batch=[20], edge_attr=[46, 3], edge_index=[2, 46], x=[20, 9], y=[1, 1])
# Batch(batch=[30], edge_attr=[68, 3], edge_index=[2, 68], x=[30, 9], y=[1, 1])
# Batch(batch=[28], edge_attr=[66, 3], edge_index=[2, 66], x=[28, 9], y=[1, 1])
# Batch(batch=[23], edge_attr=[50, 3], edge_index=[2, 50], x=[23, 9], y=[1, 1])
# Batch(batch=[40], edge_attr=[86, 3], edge_index=[2, 86], x=[40, 9], y=[1, 1])
# Batch(batch=[32], edge_attr=[68, 3], edge_index=[2, 68], x=[32, 9], y=[1, 1])
# Batch(batch=[24], edge_attr=[50, 3], edge_index=[2, 50], x=[24, 9], y=[1, 1])
# Batch(batch=[19], edge_attr=[42, 3], edge_index=[2, 42], x=[19, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[40, 3], edge_index=[2, 40], x=[18, 9], y=[1, 1])
# Batch(batch=[10], edge_attr=[22, 3], edge_index=[2, 22], x=[10, 9], y=[1, 1])
# Batch(batch=[15], edge_attr=[32, 3], edge_index=[2, 32], x=[15, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[56, 3], edge_index=[2, 56], x=[26, 9], y=[1, 1])
# Batch(batch=[30], edge_attr=[68, 3], edge_index=[2, 68], x=[30, 9], y=[1, 1])
# Batch(batch=[25], edge_attr=[56, 3], edge_index=[2, 56], x=[25, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[48, 3], edge_index=[2, 48], x=[22, 9], y=[1, 1])
# Batch(batch=[6], edge_attr=[12, 3], edge_index=[2, 12], x=[6, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[40, 3], edge_index=[2, 40], x=[18, 9], y=[1, 1])
# Batch(batch=[13], edge_attr=[26, 3], edge_index=[2, 26], x=[13, 9], y=[1, 1])
# Batch(batch=[14], edge_attr=[32, 3], edge_index=[2, 32], x=[14, 9], y=[1, 1])
# Batch(batch=[9], edge_attr=[20, 3], edge_index=[2, 20], x=[9, 9], y=[1, 1])
# Batch(batch=[10], edge_attr=[22, 3], edge_index=[2, 22], x=[10, 9], y=[1, 1])
# Batch(batch=[31], edge_attr=[68, 3], edge_index=[2, 68], x=[31, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[50, 3], edge_index=[2, 50], x=[21, 9], y=[1, 1])
# Batch(batch=[12], edge_attr=[26, 3], edge_index=[2, 26], x=[12, 9], y=[1, 1])
# Batch(batch=[19], edge_attr=[42, 3], edge_index=[2, 42], x=[19, 9], y=[1, 1])
# Batch(batch=[13], edge_attr=[28, 3], edge_index=[2, 28], x=[13, 9], y=[1, 1])
# Batch(batch=[19], edge_attr=[42, 3], edge_index=[2, 42], x=[19, 9], y=[1, 1])
# Batch(batch=[23], edge_attr=[48, 3], edge_index=[2, 48], x=[23, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[54, 3], edge_index=[2, 54], x=[26, 9], y=[1, 1])
# Batch(batch=[29], edge_attr=[66, 3], edge_index=[2, 66], x=[29, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[46, 3], edge_index=[2, 46], x=[22, 9], y=[1, 1])
# Batch(batch=[8], edge_attr=[16, 3], edge_index=[2, 16], x=[8, 9], y=[1, 1])
# Batch(batch=[24], edge_attr=[52, 3], edge_index=[2, 52], x=[24, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[48, 3], edge_index=[2, 48], x=[21, 9], y=[1, 1])
# Batch(batch=[10], edge_attr=[24, 3], edge_index=[2, 24], x=[10, 9], y=[1, 1])
# Batch(batch=[43], edge_attr=[100, 3], edge_index=[2, 100], x=[43, 9], y=[1, 1])
# Batch(batch=[15], edge_attr=[32, 3], edge_index=[2, 32], x=[15, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[58, 3], edge_index=[2, 58], x=[26, 9], y=[1, 1])
# Batch(batch=[27], edge_attr=[60, 3], edge_index=[2, 60], x=[27, 9], y=[1, 1])
# Batch(batch=[45], edge_attr=[96, 3], edge_index=[2, 96], x=[45, 9], y=[1, 1])
# Batch(batch=[11], edge_attr=[24, 3], edge_index=[2, 24], x=[11, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[44, 3], edge_index=[2, 44], x=[21, 9], y=[1, 1])
# Batch(batch=[9], edge_attr=[20, 3], edge_index=[2, 20], x=[9, 9], y=[1, 1])
# Batch(batch=[14], edge_attr=[32, 3], edge_index=[2, 32], x=[14, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[46, 3], edge_index=[2, 46], x=[21, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[46, 3], edge_index=[2, 46], x=[21, 9], y=[1, 1])
# Batch(batch=[17], edge_attr=[36, 3], edge_index=[2, 36], x=[17, 9], y=[1, 1])
# Batch(batch=[29], edge_attr=[64, 3], edge_index=[2, 64], x=[29, 9], y=[1, 1])
# Batch(batch=[17], edge_attr=[40, 3], edge_index=[2, 40], x=[17, 9], y=[1, 1])
# Batch(batch=[7], edge_attr=[14, 3], edge_index=[2, 14], x=[7, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[36, 3], edge_index=[2, 36], x=[16, 9], y=[1, 1])
# Batch(batch=[13], edge_attr=[28, 3], edge_index=[2, 28], x=[13, 9], y=[1, 1])
# Batch(batch=[10], edge_attr=[22, 3], edge_index=[2, 22], x=[10, 9], y=[1, 1])
# Batch(batch=[12], edge_attr=[28, 3], edge_index=[2, 28], x=[12, 9], y=[1, 1])
# Batch(batch=[9], edge_attr=[18, 3], edge_index=[2, 18], x=[9, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[48, 3], edge_index=[2, 48], x=[21, 9], y=[1, 1])
# Batch(batch=[25], edge_attr=[52, 3], edge_index=[2, 52], x=[25, 9], y=[1, 1])
# Batch(batch=[23], edge_attr=[48, 3], edge_index=[2, 48], x=[23, 9], y=[1, 1])
# Batch(batch=[41], edge_attr=[92, 3], edge_index=[2, 92], x=[41, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[48, 3], edge_index=[2, 48], x=[22, 9], y=[1, 1])
# Batch(batch=[20], edge_attr=[42, 3], edge_index=[2, 42], x=[20, 9], y=[1, 1])
# Batch(batch=[13], edge_attr=[28, 3], edge_index=[2, 28], x=[13, 9], y=[1, 1])
# Batch(batch=[13], edge_attr=[28, 3], edge_index=[2, 28], x=[13, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[48, 3], edge_index=[2, 48], x=[21, 9], y=[1, 1])
# Batch(batch=[13], edge_attr=[30, 3], edge_index=[2, 30], x=[13, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[42, 3], edge_index=[2, 42], x=[18, 9], y=[1, 1])
# Batch(batch=[25], edge_attr=[54, 3], edge_index=[2, 54], x=[25, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[36, 3], edge_index=[2, 36], x=[16, 9], y=[1, 1])
# Batch(batch=[10], edge_attr=[22, 3], edge_index=[2, 22], x=[10, 9], y=[1, 1])
# Batch(batch=[12], edge_attr=[26, 3], edge_index=[2, 26], x=[12, 9], y=[1, 1])
# Batch(batch=[14], edge_attr=[30, 3], edge_index=[2, 30], x=[14, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[44, 3], edge_index=[2, 44], x=[22, 9], y=[1, 1])
# Batch(batch=[12], edge_attr=[26, 3], edge_index=[2, 26], x=[12, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[42, 3], edge_index=[2, 42], x=[18, 9], y=[1, 1])
# Batch(batch=[19], edge_attr=[40, 3], edge_index=[2, 40], x=[19, 9], y=[1, 1])
# Batch(batch=[14], edge_attr=[30, 3], edge_index=[2, 30], x=[14, 9], y=[1, 1])
# Batch(batch=[14], edge_attr=[30, 3], edge_index=[2, 30], x=[14, 9], y=[1, 1])
# Batch(batch=[34], edge_attr=[74, 3], edge_index=[2, 74], x=[34, 9], y=[1, 1])
# Batch(batch=[39], edge_attr=[88, 3], edge_index=[2, 88], x=[39, 9], y=[1, 1])
# Batch(batch=[28], edge_attr=[60, 3], edge_index=[2, 60], x=[28, 9], y=[1, 1])
# Batch(batch=[20], edge_attr=[46, 3], edge_index=[2, 46], x=[20, 9], y=[1, 1])
# Batch(batch=[20], edge_attr=[46, 3], edge_index=[2, 46], x=[20, 9], y=[1, 1])
# Batch(batch=[12], edge_attr=[32, 3], edge_index=[2, 32], x=[12, 9], y=[1, 1])
# Batch(batch=[11], edge_attr=[24, 3], edge_index=[2, 24], x=[11, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[50, 3], edge_index=[2, 50], x=[22, 9], y=[1, 1])
# Batch(batch=[34], edge_attr=[68, 3], edge_index=[2, 68], x=[34, 9], y=[1, 1])
# Batch(batch=[17], edge_attr=[38, 3], edge_index=[2, 38], x=[17, 9], y=[1, 1])
# Batch(batch=[29], edge_attr=[66, 3], edge_index=[2, 66], x=[29, 9], y=[1, 1])
# Batch(batch=[20], edge_attr=[46, 3], edge_index=[2, 46], x=[20, 9], y=[1, 1])
# Batch(batch=[38], edge_attr=[84, 3], edge_index=[2, 84], x=[38, 9], y=[1, 1])
# Batch(batch=[50], edge_attr=[112, 3], edge_index=[2, 112], x=[50, 9], y=[1, 1])
# Batch(batch=[34], edge_attr=[78, 3], edge_index=[2, 78], x=[34, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[46, 3], edge_index=[2, 46], x=[22, 9], y=[1, 1])
# Batch(batch=[28], edge_attr=[58, 3], edge_index=[2, 58], x=[28, 9], y=[1, 1])
# Batch(batch=[19], edge_attr=[40, 3], edge_index=[2, 40], x=[19, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[34, 3], edge_index=[2, 34], x=[16, 9], y=[1, 1])
# Batch(batch=[48], edge_attr=[108, 3], edge_index=[2, 108], x=[48, 9], y=[1, 1])
# Batch(batch=[15], edge_attr=[32, 3], edge_index=[2, 32], x=[15, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[34, 3], edge_index=[2, 34], x=[16, 9], y=[1, 1])
# Batch(batch=[15], edge_attr=[34, 3], edge_index=[2, 34], x=[15, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[50, 3], edge_index=[2, 50], x=[21, 9], y=[1, 1])
# Batch(batch=[9], edge_attr=[20, 3], edge_index=[2, 20], x=[9, 9], y=[1, 1])
# Batch(batch=[19], edge_attr=[42, 3], edge_index=[2, 42], x=[19, 9], y=[1, 1])
# Batch(batch=[23], edge_attr=[50, 3], edge_index=[2, 50], x=[23, 9], y=[1, 1])
# Batch(batch=[31], edge_attr=[68, 3], edge_index=[2, 68], x=[31, 9], y=[1, 1])
# Batch(batch=[19], edge_attr=[42, 3], edge_index=[2, 42], x=[19, 9], y=[1, 1])
# Batch(batch=[17], edge_attr=[36, 3], edge_index=[2, 36], x=[17, 9], y=[1, 1])
# Batch(batch=[56], edge_attr=[124, 3], edge_index=[2, 124], x=[56, 9], y=[1, 1])
# Batch(batch=[12], edge_attr=[26, 3], edge_index=[2, 26], x=[12, 9], y=[1, 1])
# Batch(batch=[28], edge_attr=[62, 3], edge_index=[2, 62], x=[28, 9], y=[1, 1])
# Batch(batch=[20], edge_attr=[42, 3], edge_index=[2, 42], x=[20, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[56, 3], edge_index=[2, 56], x=[26, 9], y=[1, 1])
# Batch(batch=[14], edge_attr=[30, 3], edge_index=[2, 30], x=[14, 9], y=[1, 1])
# Batch(batch=[12], edge_attr=[26, 3], edge_index=[2, 26], x=[12, 9], y=[1, 1])
# Batch(batch=[84], edge_attr=[182, 3], edge_index=[2, 182], x=[84, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[46, 3], edge_index=[2, 46], x=[21, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[44, 3], edge_index=[2, 44], x=[21, 9], y=[1, 1])
# Batch(batch=[19], edge_attr=[42, 3], edge_index=[2, 42], x=[19, 9], y=[1, 1])
# Batch(batch=[40], edge_attr=[94, 3], edge_index=[2, 94], x=[40, 9], y=[1, 1])
# Batch(batch=[50], edge_attr=[106, 3], edge_index=[2, 106], x=[50, 9], y=[1, 1])
# Batch(batch=[37], edge_attr=[86, 3], edge_index=[2, 86], x=[37, 9], y=[1, 1])
# Batch(batch=[66], edge_attr=[146, 3], edge_index=[2, 146], x=[66, 9], y=[1, 1])
# Batch(batch=[28], edge_attr=[60, 3], edge_index=[2, 60], x=[28, 9], y=[1, 1])
# Batch(batch=[32], edge_attr=[72, 3], edge_index=[2, 72], x=[32, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[46, 3], edge_index=[2, 46], x=[22, 9], y=[1, 1])
# Batch(batch=[29], edge_attr=[64, 3], edge_index=[2, 64], x=[29, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[38, 3], edge_index=[2, 38], x=[18, 9], y=[1, 1])
# Batch(batch=[25], edge_attr=[56, 3], edge_index=[2, 56], x=[25, 9], y=[1, 1])
# Batch(batch=[9], edge_attr=[18, 3], edge_index=[2, 18], x=[9, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[38, 3], edge_index=[2, 38], x=[18, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[48, 3], edge_index=[2, 48], x=[21, 9], y=[1, 1])
# Batch(batch=[56], edge_attr=[116, 3], edge_index=[2, 116], x=[56, 9], y=[1, 1])
# Batch(batch=[13], edge_attr=[28, 3], edge_index=[2, 28], x=[13, 9], y=[1, 1])
# Batch(batch=[54], edge_attr=[118, 3], edge_index=[2, 118], x=[54, 9], y=[1, 1])
# Batch(batch=[23], edge_attr=[52, 3], edge_index=[2, 52], x=[23, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[34, 3], edge_index=[2, 34], x=[16, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[34, 3], edge_index=[2, 34], x=[16, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[34, 3], edge_index=[2, 34], x=[16, 9], y=[1, 1])
# Batch(batch=[14], edge_attr=[30, 3], edge_index=[2, 30], x=[14, 9], y=[1, 1])
# Batch(batch=[23], edge_attr=[50, 3], edge_index=[2, 50], x=[23, 9], y=[1, 1])
# Batch(batch=[23], edge_attr=[50, 3], edge_index=[2, 50], x=[23, 9], y=[1, 1])
# Batch(batch=[23], edge_attr=[50, 3], edge_index=[2, 50], x=[23, 9], y=[1, 1])
# Batch(batch=[28], edge_attr=[62, 3], edge_index=[2, 62], x=[28, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[34, 3], edge_index=[2, 34], x=[16, 9], y=[1, 1])
# Batch(batch=[23], edge_attr=[52, 3], edge_index=[2, 52], x=[23, 9], y=[1, 1])
# Batch(batch=[32], edge_attr=[68, 3], edge_index=[2, 68], x=[32, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[52, 3], edge_index=[2, 52], x=[22, 9], y=[1, 1])
# Batch(batch=[47], edge_attr=[104, 3], edge_index=[2, 104], x=[47, 9], y=[1, 1])
# Batch(batch=[46], edge_attr=[100, 3], edge_index=[2, 100], x=[46, 9], y=[1, 1])
# Batch(batch=[36], edge_attr=[78, 3], edge_index=[2, 78], x=[36, 9], y=[1, 1])
# Batch(batch=[43], edge_attr=[94, 3], edge_index=[2, 94], x=[43, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[46, 3], edge_index=[2, 46], x=[22, 9], y=[1, 1])
# Batch(batch=[15], edge_attr=[34, 3], edge_index=[2, 34], x=[15, 9], y=[1, 1])
# Batch(batch=[12], edge_attr=[26, 3], edge_index=[2, 26], x=[12, 9], y=[1, 1])
# Batch(batch=[14], edge_attr=[30, 3], edge_index=[2, 30], x=[14, 9], y=[1, 1])
# Batch(batch=[15], edge_attr=[32, 3], edge_index=[2, 32], x=[15, 9], y=[1, 1])
# Batch(batch=[13], edge_attr=[28, 3], edge_index=[2, 28], x=[13, 9], y=[1, 1])
# Batch(batch=[19], edge_attr=[40, 3], edge_index=[2, 40], x=[19, 9], y=[1, 1])
# Batch(batch=[44], edge_attr=[96, 3], edge_index=[2, 96], x=[44, 9], y=[1, 1])
# Batch(batch=[27], edge_attr=[64, 3], edge_index=[2, 64], x=[27, 9], y=[1, 1])
# Batch(batch=[13], edge_attr=[26, 3], edge_index=[2, 26], x=[13, 9], y=[1, 1])
# Batch(batch=[43], edge_attr=[96, 3], edge_index=[2, 96], x=[43, 9], y=[1, 1])
# Batch(batch=[23], edge_attr=[50, 3], edge_index=[2, 50], x=[23, 9], y=[1, 1])
# Batch(batch=[29], edge_attr=[66, 3], edge_index=[2, 66], x=[29, 9], y=[1, 1])
# Batch(batch=[44], edge_attr=[94, 3], edge_index=[2, 94], x=[44, 9], y=[1, 1])
# Batch(batch=[41], edge_attr=[90, 3], edge_index=[2, 90], x=[41, 9], y=[1, 1])
# Batch(batch=[50], edge_attr=[110, 3], edge_index=[2, 110], x=[50, 9], y=[1, 1])
# Batch(batch=[50], edge_attr=[110, 3], edge_index=[2, 110], x=[50, 9], y=[1, 1])
# Batch(batch=[61], edge_attr=[134, 3], edge_index=[2, 134], x=[61, 9], y=[1, 1])
# Batch(batch=[17], edge_attr=[36, 3], edge_index=[2, 36], x=[17, 9], y=[1, 1])
# Batch(batch=[20], edge_attr=[42, 3], edge_index=[2, 42], x=[20, 9], y=[1, 1])
# Batch(batch=[19], edge_attr=[38, 3], edge_index=[2, 38], x=[19, 9], y=[1, 1])
# Batch(batch=[14], edge_attr=[30, 3], edge_index=[2, 30], x=[14, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[48, 3], edge_index=[2, 48], x=[22, 9], y=[1, 1])
# Batch(batch=[31], edge_attr=[68, 3], edge_index=[2, 68], x=[31, 9], y=[1, 1])
# Batch(batch=[121], edge_attr=[250, 3], edge_index=[2, 250], x=[121, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[60, 3], edge_index=[2, 60], x=[26, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[56, 3], edge_index=[2, 56], x=[26, 9], y=[1, 1])
# Batch(batch=[13], edge_attr=[28, 3], edge_index=[2, 28], x=[13, 9], y=[1, 1])
# Batch(batch=[36], edge_attr=[78, 3], edge_index=[2, 78], x=[36, 9], y=[1, 1])
# Batch(batch=[30], edge_attr=[66, 3], edge_index=[2, 66], x=[30, 9], y=[1, 1])
# Batch(batch=[37], edge_attr=[80, 3], edge_index=[2, 80], x=[37, 9], y=[1, 1])
# Batch(batch=[42], edge_attr=[92, 3], edge_index=[2, 92], x=[42, 9], y=[1, 1])
# Batch(batch=[40], edge_attr=[88, 3], edge_index=[2, 88], x=[40, 9], y=[1, 1])
# Batch(batch=[55], edge_attr=[118, 3], edge_index=[2, 118], x=[55, 9], y=[1, 1])
# Batch(batch=[45], edge_attr=[100, 3], edge_index=[2, 100], x=[45, 9], y=[1, 1])
# Batch(batch=[46], edge_attr=[104, 3], edge_index=[2, 104], x=[46, 9], y=[1, 1])
# Batch(batch=[54], edge_attr=[118, 3], edge_index=[2, 118], x=[54, 9], y=[1, 1])
# Batch(batch=[54], edge_attr=[118, 3], edge_index=[2, 118], x=[54, 9], y=[1, 1])
# Batch(batch=[56], edge_attr=[122, 3], edge_index=[2, 122], x=[56, 9], y=[1, 1])
# Batch(batch=[58], edge_attr=[126, 3], edge_index=[2, 126], x=[58, 9], y=[1, 1])
# Batch(batch=[56], edge_attr=[124, 3], edge_index=[2, 124], x=[56, 9], y=[1, 1])
# Batch(batch=[63], edge_attr=[138, 3], edge_index=[2, 138], x=[63, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[48, 3], edge_index=[2, 48], x=[22, 9], y=[1, 1])
# Batch(batch=[14], edge_attr=[32, 3], edge_index=[2, 32], x=[14, 9], y=[1, 1])
# Batch(batch=[12], edge_attr=[24, 3], edge_index=[2, 24], x=[12, 9], y=[1, 1])
# Batch(batch=[60], edge_attr=[132, 3], edge_index=[2, 132], x=[60, 9], y=[1, 1])
# Batch(batch=[23], edge_attr=[50, 3], edge_index=[2, 50], x=[23, 9], y=[1, 1])
# Batch(batch=[24], edge_attr=[52, 3], edge_index=[2, 52], x=[24, 9], y=[1, 1])
# Batch(batch=[27], edge_attr=[58, 3], edge_index=[2, 58], x=[27, 9], y=[1, 1])
# Batch(batch=[14], edge_attr=[30, 3], edge_index=[2, 30], x=[14, 9], y=[1, 1])
# Batch(batch=[38], edge_attr=[84, 3], edge_index=[2, 84], x=[38, 9], y=[1, 1])
# Batch(batch=[14], edge_attr=[32, 3], edge_index=[2, 32], x=[14, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[46, 3], edge_index=[2, 46], x=[21, 9], y=[1, 1])
# Batch(batch=[13], edge_attr=[28, 3], edge_index=[2, 28], x=[13, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[48, 3], edge_index=[2, 48], x=[22, 9], y=[1, 1])
# Batch(batch=[13], edge_attr=[30, 3], edge_index=[2, 30], x=[13, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[48, 3], edge_index=[2, 48], x=[21, 9], y=[1, 1])
# Batch(batch=[59], edge_attr=[124, 3], edge_index=[2, 124], x=[59, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[56, 3], edge_index=[2, 56], x=[26, 9], y=[1, 1])
# Batch(batch=[8], edge_attr=[18, 3], edge_index=[2, 18], x=[8, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[58, 3], edge_index=[2, 58], x=[26, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[40, 3], edge_index=[2, 40], x=[18, 9], y=[1, 1])
# Batch(batch=[24], edge_attr=[48, 3], edge_index=[2, 48], x=[24, 9], y=[1, 1])
# Batch(batch=[14], edge_attr=[30, 3], edge_index=[2, 30], x=[14, 9], y=[1, 1])
# Batch(batch=[14], edge_attr=[30, 3], edge_index=[2, 30], x=[14, 9], y=[1, 1])
# Batch(batch=[31], edge_attr=[72, 3], edge_index=[2, 72], x=[31, 9], y=[1, 1])
# Batch(batch=[49], edge_attr=[108, 3], edge_index=[2, 108], x=[49, 9], y=[1, 1])
# Batch(batch=[20], edge_attr=[44, 3], edge_index=[2, 44], x=[20, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[56, 3], edge_index=[2, 56], x=[26, 9], y=[1, 1])
# Batch(batch=[38], edge_attr=[84, 3], edge_index=[2, 84], x=[38, 9], y=[1, 1])
# Batch(batch=[27], edge_attr=[58, 3], edge_index=[2, 58], x=[27, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[40, 3], edge_index=[2, 40], x=[18, 9], y=[1, 1])
# Batch(batch=[19], edge_attr=[44, 3], edge_index=[2, 44], x=[19, 9], y=[1, 1])
# Batch(batch=[25], edge_attr=[60, 3], edge_index=[2, 60], x=[25, 9], y=[1, 1])
# Batch(batch=[13], edge_attr=[30, 3], edge_index=[2, 30], x=[13, 9], y=[1, 1])
# Batch(batch=[32], edge_attr=[72, 3], edge_index=[2, 72], x=[32, 9], y=[1, 1])
# Batch(batch=[40], edge_attr=[84, 3], edge_index=[2, 84], x=[40, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[38, 3], edge_index=[2, 38], x=[18, 9], y=[1, 1])
# Batch(batch=[15], edge_attr=[36, 3], edge_index=[2, 36], x=[15, 9], y=[1, 1])
# Batch(batch=[25], edge_attr=[60, 3], edge_index=[2, 60], x=[25, 9], y=[1, 1])
# Batch(batch=[30], edge_attr=[70, 3], edge_index=[2, 70], x=[30, 9], y=[1, 1])
# Batch(batch=[39], edge_attr=[84, 3], edge_index=[2, 84], x=[39, 9], y=[1, 1])
# Batch(batch=[38], edge_attr=[82, 3], edge_index=[2, 82], x=[38, 9], y=[1, 1])
# Batch(batch=[8], edge_attr=[18, 3], edge_index=[2, 18], x=[8, 9], y=[1, 1])
# Batch(batch=[14], edge_attr=[32, 3], edge_index=[2, 32], x=[14, 9], y=[1, 1])
# Batch(batch=[38], edge_attr=[86, 3], edge_index=[2, 86], x=[38, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[46, 3], edge_index=[2, 46], x=[21, 9], y=[1, 1])
# Batch(batch=[20], edge_attr=[46, 3], edge_index=[2, 46], x=[20, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[34, 3], edge_index=[2, 34], x=[16, 9], y=[1, 1])
# Batch(batch=[17], edge_attr=[38, 3], edge_index=[2, 38], x=[17, 9], y=[1, 1])
# Batch(batch=[30], edge_attr=[68, 3], edge_index=[2, 68], x=[30, 9], y=[1, 1])
# Batch(batch=[20], edge_attr=[42, 3], edge_index=[2, 42], x=[20, 9], y=[1, 1])
# Batch(batch=[12], edge_attr=[24, 3], edge_index=[2, 24], x=[12, 9], y=[1, 1])
# Batch(batch=[38], edge_attr=[82, 3], edge_index=[2, 82], x=[38, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[46, 3], edge_index=[2, 46], x=[21, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[50, 3], edge_index=[2, 50], x=[22, 9], y=[1, 1])
# Batch(batch=[20], edge_attr=[46, 3], edge_index=[2, 46], x=[20, 9], y=[1, 1])
# Batch(batch=[13], edge_attr=[28, 3], edge_index=[2, 28], x=[13, 9], y=[1, 1])
# Batch(batch=[15], edge_attr=[32, 3], edge_index=[2, 32], x=[15, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[38, 3], edge_index=[2, 38], x=[18, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[46, 3], edge_index=[2, 46], x=[22, 9], y=[1, 1])
# Batch(batch=[31], edge_attr=[68, 3], edge_index=[2, 68], x=[31, 9], y=[1, 1])
# Batch(batch=[27], edge_attr=[62, 3], edge_index=[2, 62], x=[27, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[46, 3], edge_index=[2, 46], x=[22, 9], y=[1, 1])
# Batch(batch=[25], edge_attr=[54, 3], edge_index=[2, 54], x=[25, 9], y=[1, 1])
# Batch(batch=[36], edge_attr=[78, 3], edge_index=[2, 78], x=[36, 9], y=[1, 1])
# Batch(batch=[27], edge_attr=[60, 3], edge_index=[2, 60], x=[27, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[54, 3], edge_index=[2, 54], x=[26, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[40, 3], edge_index=[2, 40], x=[18, 9], y=[1, 1])
# Batch(batch=[45], edge_attr=[96, 3], edge_index=[2, 96], x=[45, 9], y=[1, 1])
# Batch(batch=[27], edge_attr=[60, 3], edge_index=[2, 60], x=[27, 9], y=[1, 1])
# Batch(batch=[31], edge_attr=[70, 3], edge_index=[2, 70], x=[31, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[36, 3], edge_index=[2, 36], x=[16, 9], y=[1, 1])
# Batch(batch=[20], edge_attr=[44, 3], edge_index=[2, 44], x=[20, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[46, 3], edge_index=[2, 46], x=[21, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[48, 3], edge_index=[2, 48], x=[21, 9], y=[1, 1])
# Batch(batch=[20], edge_attr=[46, 3], edge_index=[2, 46], x=[20, 9], y=[1, 1])
# Batch(batch=[11], edge_attr=[24, 3], edge_index=[2, 24], x=[11, 9], y=[1, 1])
# Batch(batch=[9], edge_attr=[20, 3], edge_index=[2, 20], x=[9, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[62, 3], edge_index=[2, 62], x=[26, 9], y=[1, 1])
# Batch(batch=[28], edge_attr=[60, 3], edge_index=[2, 60], x=[28, 9], y=[1, 1])
# Batch(batch=[14], edge_attr=[30, 3], edge_index=[2, 30], x=[14, 9], y=[1, 1])
# Batch(batch=[17], edge_attr=[36, 3], edge_index=[2, 36], x=[17, 9], y=[1, 1])
# Batch(batch=[24], edge_attr=[52, 3], edge_index=[2, 52], x=[24, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[46, 3], edge_index=[2, 46], x=[21, 9], y=[1, 1])
# Batch(batch=[19], edge_attr=[42, 3], edge_index=[2, 42], x=[19, 9], y=[1, 1])
# Batch(batch=[23], edge_attr=[52, 3], edge_index=[2, 52], x=[23, 9], y=[1, 1])
# Batch(batch=[32], edge_attr=[66, 3], edge_index=[2, 66], x=[32, 9], y=[1, 1])
# Batch(batch=[62], edge_attr=[130, 3], edge_index=[2, 130], x=[62, 9], y=[1, 1])
# Batch(batch=[13], edge_attr=[28, 3], edge_index=[2, 28], x=[13, 9], y=[1, 1])
# Batch(batch=[20], edge_attr=[44, 3], edge_index=[2, 44], x=[20, 9], y=[1, 1])
# Batch(batch=[29], edge_attr=[62, 3], edge_index=[2, 62], x=[29, 9], y=[1, 1])
# Batch(batch=[25], edge_attr=[56, 3], edge_index=[2, 56], x=[25, 9], y=[1, 1])
# Batch(batch=[11], edge_attr=[24, 3], edge_index=[2, 24], x=[11, 9], y=[1, 1])
# Batch(batch=[20], edge_attr=[44, 3], edge_index=[2, 44], x=[20, 9], y=[1, 1])
# Batch(batch=[10], edge_attr=[22, 3], edge_index=[2, 22], x=[10, 9], y=[1, 1])
# Batch(batch=[17], edge_attr=[36, 3], edge_index=[2, 36], x=[17, 9], y=[1, 1])
# Batch(batch=[35], edge_attr=[72, 3], edge_index=[2, 72], x=[35, 9], y=[1, 1])
# Batch(batch=[37], edge_attr=[78, 3], edge_index=[2, 78], x=[37, 9], y=[1, 1])
# Batch(batch=[35], edge_attr=[80, 3], edge_index=[2, 80], x=[35, 9], y=[1, 1])
# Batch(batch=[11], edge_attr=[24, 3], edge_index=[2, 24], x=[11, 9], y=[1, 1])
# Batch(batch=[20], edge_attr=[42, 3], edge_index=[2, 42], x=[20, 9], y=[1, 1])
# Batch(batch=[27], edge_attr=[58, 3], edge_index=[2, 58], x=[27, 9], y=[1, 1])
# Batch(batch=[11], edge_attr=[24, 3], edge_index=[2, 24], x=[11, 9], y=[1, 1])
# Batch(batch=[23], edge_attr=[54, 3], edge_index=[2, 54], x=[23, 9], y=[1, 1])
# Batch(batch=[20], edge_attr=[46, 3], edge_index=[2, 46], x=[20, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[38, 3], edge_index=[2, 38], x=[18, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[40, 3], edge_index=[2, 40], x=[18, 9], y=[1, 1])
# Batch(batch=[20], edge_attr=[46, 3], edge_index=[2, 46], x=[20, 9], y=[1, 1])
# Batch(batch=[11], edge_attr=[22, 3], edge_index=[2, 22], x=[11, 9], y=[1, 1])
# Batch(batch=[28], edge_attr=[64, 3], edge_index=[2, 64], x=[28, 9], y=[1, 1])
# Batch(batch=[13], edge_attr=[28, 3], edge_index=[2, 28], x=[13, 9], y=[1, 1])
# Batch(batch=[12], edge_attr=[24, 3], edge_index=[2, 24], x=[12, 9], y=[1, 1])
# Batch(batch=[25], edge_attr=[60, 3], edge_index=[2, 60], x=[25, 9], y=[1, 1])
# Batch(batch=[27], edge_attr=[60, 3], edge_index=[2, 60], x=[27, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[58, 3], edge_index=[2, 58], x=[26, 9], y=[1, 1])
# Batch(batch=[29], edge_attr=[64, 3], edge_index=[2, 64], x=[29, 9], y=[1, 1])
# Batch(batch=[12], edge_attr=[26, 3], edge_index=[2, 26], x=[12, 9], y=[1, 1])
# Batch(batch=[13], edge_attr=[32, 3], edge_index=[2, 32], x=[13, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[56, 3], edge_index=[2, 56], x=[26, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[56, 3], edge_index=[2, 56], x=[26, 9], y=[1, 1])
# Batch(batch=[27], edge_attr=[58, 3], edge_index=[2, 58], x=[27, 9], y=[1, 1])
# Batch(batch=[24], edge_attr=[52, 3], edge_index=[2, 52], x=[24, 9], y=[1, 1])
# Batch(batch=[27], edge_attr=[62, 3], edge_index=[2, 62], x=[27, 9], y=[1, 1])
# Batch(batch=[24], edge_attr=[50, 3], edge_index=[2, 50], x=[24, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[48, 3], edge_index=[2, 48], x=[21, 9], y=[1, 1])
# Batch(batch=[26], edge_attr=[54, 3], edge_index=[2, 54], x=[26, 9], y=[1, 1])
# Batch(batch=[27], edge_attr=[60, 3], edge_index=[2, 60], x=[27, 9], y=[1, 1])
# Batch(batch=[47], edge_attr=[102, 3], edge_index=[2, 102], x=[47, 9], y=[1, 1])
# Batch(batch=[18], edge_attr=[36, 3], edge_index=[2, 36], x=[18, 9], y=[1, 1])
# Batch(batch=[21], edge_attr=[46, 3], edge_index=[2, 46], x=[21, 9], y=[1, 1])
# Batch(batch=[46], edge_attr=[94, 3], edge_index=[2, 94], x=[46, 9], y=[1, 1])
# Batch(batch=[12], edge_attr=[26, 3], edge_index=[2, 26], x=[12, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[50, 3], edge_index=[2, 50], x=[22, 9], y=[1, 1])
# Batch(batch=[27], edge_attr=[58, 3], edge_index=[2, 58], x=[27, 9], y=[1, 1])
# Batch(batch=[24], edge_attr=[52, 3], edge_index=[2, 52], x=[24, 9], y=[1, 1])
# Batch(batch=[32], edge_attr=[68, 3], edge_index=[2, 68], x=[32, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[46, 3], edge_index=[2, 46], x=[22, 9], y=[1, 1])
# Batch(batch=[16], edge_attr=[34, 3], edge_index=[2, 34], x=[16, 9], y=[1, 1])
# Batch(batch=[11], edge_attr=[22, 3], edge_index=[2, 22], x=[11, 9], y=[1, 1])
# Batch(batch=[10], edge_attr=[20, 3], edge_index=[2, 20], x=[10, 9], y=[1, 1])
# Batch(batch=[48], edge_attr=[104, 3], edge_index=[2, 104], x=[48, 9], y=[1, 1])
# Batch(batch=[22], edge_attr=[48, 3], edge_index=[2, 48], x=[22, 9], y=[1, 1])
# Batch(batch=[29], edge_attr=[58, 3], edge_index=[2, 58], x=[29, 9], y=[1, 1])
# ...
# 0 -2.8785086
# 0 -2.7615762
# 0 -3.5106373
# 0 -3.8969908
# 0 -3.8926086
# 0 -3.9344983
# 0 -3.9297714
# 0 -3.2358117
# 0 -2.5356617
# 0 -3.9247913
# 0 -3.9517174
# 0 -3.3411984
# 0 -3.7169747
# 0 -4.49381
# 0 -3.7165184
# 0 -3.3415642
# 0 -4.8480616
# 0 -3.9432259
# 0 -3.9735513
# 0 -2.6758647
# 0 -4.090872
# 0 -4.273285
# 0 -3.155932
# 0 -3.403718
# 0 -3.9851108
# 0 -3.883019
# 0 -2.8793597
# 0 -4.247788
# 0 -3.912949
# 0 -3.0935416
# 0 -3.6686444
# 0 -3.6133213
# 0 -3.9958959
# 0 -3.0107455
# 0 -2.271716
# 0 -3.8305545
# 0 -3.6951456
# 0 -5.685865
# 0 -3.465333
# 0 -3.4884062
# 0 -3.3635635
# 0 -3.9592624
# 0 -4.117089
# 0 -3.9199138
# 0 -3.837624
# 0 -3.388731
# 0 -3.7034154
# 0 -3.8186588
# 0 -3.135243
# 0 -3.6375756
# 0 -4.176281
# 0 -4.219464
# 0 -4.4987683
# 0 -3.777183
# 0 -3.2203345
# 0 -3.8609457
# 0 -4.0021176
# 0 -3.8965106
# 0 -3.9019508
# 0 -3.4822178
# 0 -3.2253194
# 0 -3.2140932
# 0 -4.9219127
# 0 -3.502232
# 0 -3.6266994
# 0 -3.355945
# 0 -3.4727516
# 0 -3.912582
# 0 -3.90454
# 0 -3.914989
# 0 -3.8343034
# 0 -3.4204779
# 0 -2.9620824
# 0 -3.772284
# 0 -3.4365258
# 0 -3.7442203
# 0 -2.998664
# 0 -3.843472
# 0 -3.81137
# 0 -3.1209073
# 0 -3.711237
# 0 -2.7601752
# 0 -5.5475917
# 0 -4.7317915
# 0 -3.7381172
# 0 -3.3237739
# 0 -3.856268
# 0 -3.3754778
# 0 -3.332559
# 0 -3.5287948
# 0 -3.546535
# 0 -3.7950964
# 0 -3.434986
# 0 -2.4491925
# 0 -3.7124763
# 0 -3.9296517
# 0 -3.6178684
# 0 -3.8290195
# 0 -3.4285183
# 0 -3.569532
# 0 -4.4715886
# 0 -2.4229617
# 0 -3.5473824
# 0 -3.7149591
# 0 -3.8230462
# 0 -3.8642793
# 0 -3.454578
# 0 -3.3888774
# 0 -4.411341
# 1 -4.2685423
# 0 -3.7974448
# 0 -3.699974
# 0 -3.514844
# 0 -3.445187
# 0 -6.833998
# 0 -3.1753273
# 0 -2.052991
# 0 -3.168943
# 0 -2.0670037
# 0 -3.771081
# 0 -3.5137258
# 0 -3.1793046
# 0 -4.191013
# 0 -3.8081598
# 0 -4.0687504
# 0 -3.9737926
# 0 -4.0561485
# 0 -3.3112922
# 0 -3.4472704
# 0 -3.5815468
# 0 -3.616445
# 0 -3.5509262
# 0 -3.1917362
# 0 -4.0865088
# 0 -3.6718664
# 0 -3.8323398
# 0 -2.7911758
# 0 -2.7507572
# 0 -1.9598616
# 0 -4.4207306
# 0 -4.2636733
# 0 -3.762251
# 0 -3.9752603
# 0 -3.5715141
# 0 -3.6291943
# 0 -3.6907568
# 0 -3.808425
# 0 -3.6188965
# 0 -3.9241467
# 0 -3.4526396
# 0 -2.6768346
# 0 -3.0420861
# 0 -3.7263093
# 0 -3.8530269
# 0 -3.621159
# 0 -3.7569537
# 0 -4.4927454
# 0 -3.8344083
# 0 -3.6530876
# 0 -2.287181
# 0 -5.025265
# 1 -6.4907627
# 0 -3.3473144
# 0 -4.018557
# 0 -2.3550143
# 0 -2.5930963
# 0 -4.1416926
# 0 -3.2474356
# 0 -4.869843
# 0 -3.7509065
# 0 -3.7810497
# 0 -3.8255095
# 0 -3.6787348
# 0 -3.822764
# 0 -3.6144304
# 0 -3.778143
# 0 -3.6260247
# 0 -3.4011683
# 0 -3.9772286
# 0 -3.8259354
# 0 -3.8770118
# 0 -3.4276643
# 0 -3.8760538
# 0 -3.904151
# 0 -2.879932
# 0 -3.513719
# 0 -4.176946
# 0 -4.0305076
# 0 -3.6670275
# 0 -3.9103532
# 0 -3.3099089
# 0 -4.5785804
# 0 -2.8676476
# 0 -2.876001
# 0 -2.8988705
# 0 -3.8795962
# 0 -3.0749588
# 0 -3.6974735
# 0 -4.257158
# 0 -3.5576053
# 0 -2.3208494
# 0 -3.0155177
# 0 -3.7108045
# 0 -4.856704
# 1 -2.3873081
# 0 -5.409187
# 0 -4.243667
# 0 -2.5843492
# 0 -2.4433174
# 0 -2.8167338
# 1 -2.4296556
# 0 -3.0701222
# 0 -2.9064713
# 0 -3.6540956
# 0 -3.2653513
# 0 -3.7932386
# 0 -3.7368612
# 0 -4.0485144
# 0 -3.3732758
# 1 -3.10852
# 0 -2.760346
# 0 -3.5192337
# 0 -2.6825986
# 0 -2.0155725
# 1 -4.522541
# 0 -3.0948544
# 0 -3.2469716
# 0 -4.3543983
# 0 -3.7700453
# 1 -3.2576718
# 0 -3.3680825
# 0 -3.313336
# 0 -3.0747352
# 0 -4.214434
# 0 -4.091525
# 0 -3.8829708
# 0 -3.6629562
# 0 -3.7673721
# 0 -4.063586
# 0 -3.8946004
# 0 -3.6672177
# 0 -2.5815225
# 0 -3.4933472
# 0 -4.496888
# 0 -3.989153
# 0 -4.5079007
# 0 -4.7046847
# 0 -3.9921746
# 0 -3.0449944
# 0 -2.9741488
# 0 -4.8184795
# 0 -2.9879613
# 0 -3.7978702
# 0 -2.9369702
# 0 -2.8059058
# 0 -4.8826275
# 0 -3.7193112
# 0 -3.5964231
# 0 -3.176094
# 0 -3.8445091
# 0 -3.6761823
# 0 -3.776445
# 0 -3.6878562
# 0 -3.893806
# 0 -2.675655
# 0 -3.8098702
# 0 -4.034942
# 0 -3.9511843
# 0 -3.32614
# 0 -3.5059
# 0 -2.6272225
# 0 -3.760511
# 0 -2.9114342
# 0 -3.4277916
# 0 -4.9195795
# 0 -3.7563982
# 0 -2.626339
# 0 -3.5613809
# 0 -3.6619039
# 0 -3.42622
# 0 -2.6805563
# 0 -3.6590004
# 0 -4.143644
# 0 -4.1822095
# 0 -3.9703712
# 0 -3.9262571
# 0 -3.9247017
# 0 -4.305983
# 0 -2.6147494
# 0 -3.5014782
# 0 -3.249422
# 0 -3.1754298
# 0 -3.462326
# 1 -4.867461
# 0 -3.8854299
# 0 -3.398621
# 0 -3.9449806
# 0 -4.048551
# 0 -4.0442333
# 0 -3.9131632
# 0 -3.3092031
# 0 -3.6544614
# 0 -3.0854673
# 0 -3.7194796
# 0 -4.1287727
# 0 -4.7828374
# 0 -2.2779102
# 0 -3.4865966
# 0 -4.4400916
# 0 -3.344841
# 0 -3.9251552
# 0 -3.3771062
# 0 -4.5614686
# 0 -3.1186905
# 0 -3.353242
# 0 -3.5519767
# 0 -3.7184162
# 0 -3.7505054
# 0 -3.7839856
# 0 -3.75285
# 0 -4.20921
# 0 -3.4461536
# 0 -3.696631
# 0 -3.7843003
# 0 -2.7074776
# 0 -3.3901215
# 0 -5.396486
# 0 -4.4337125
# 0 -4.402729
# 0 -4.3222513
# 0 -3.3262477
# 0 -2.8024483
# 0 -3.0316615
# 0 -4.01326
# 0 -3.1934872
# 0 -3.4464545
# 0 -4.797696
# 0 -3.711802
# 0 -3.5797524
# 0 -3.4139671
# 0 -3.742237
# 0 -3.43953
# 0 -3.524578
# 0 -3.0006757
# 0 -3.1675096
# 0 -3.7258492
# 0 -4.468604
# 0 -2.5554342
# 0 -2.6735277
# 0 -3.640585
# 0 -3.9294457
# 0 -3.877133
# 0 -3.1016316
# 0 -3.8313432
# 0 -3.748744
# 0 -3.803594
# 0 -3.9703798
# 0 -3.3516064
# 0 -2.9311552
# 0 -3.53574
# 0 -4.3642163
# 0 -3.8598142
# 0 -4.838737
# 0 -4.6896625
# 0 -4.6458087
# 0 -4.5856566
# 0 -4.557999
# 0 -4.383366
# 0 -4.439347
# 0 -4.421975
# 0 -4.828983
# 0 -4.504541
# 0 -4.3335967
# 0 -4.588181
# 0 -4.472126
# 0 -4.5941434
# 0 -4.5337996
# 0 -4.5646205
# 0 -3.123011
# 0 -3.0071821
# 0 -3.1822262
# 0 -3.4748058
# 0 -3.5550117
# 0 -3.7734747
# 0 -4.0019593
# 0 -3.82931
# 0 -3.8385296
# 0 -3.6844969
# 0 -3.1975079
# 0 -3.657589
# 0 -3.450469
# 0 -3.6422815
# 0 -3.5255895
# 0 -4.46452
# 0 -3.6256294
# 0 -5.596503
# 0 -4.109091
# 0 -3.1520991
# 0 -3.4408236
# 1 -2.8139548
# 0 -3.4006367
# 0 -3.296413
# 0 -3.321711
# 0 -3.3403363
# 0 -4.0636125
# 0 -4.042981
# 0 -3.0210757
# 0 -3.9217253
# 0 -3.9982147
# 0 -3.8778272
# 0 -3.340129
# 0 -3.052311
# 0 -3.5396647
# 1 -3.632978
# 0 -3.6621284
# 0 -3.2099762
# 0 -3.8941565
# 0 -2.954403
# 0 -1.9195653
# 0 -2.9032097
# 0 -3.8176575
# 0 -3.912202
# 0 -4.9850607
# 0 -3.8717947
# 0 -3.4554992
# 0 -3.286903
# 0 -3.5621567
# 0 -3.4928422
# 0 -3.5026674
# 0 -3.3514752
# 0 -5.0778704
# 0 -5.0220466
# 0 -3.2249255
# 0 -3.1478772
# 1 -2.2794027
# 0 -3.473827
# 0 -4.055996
# 0 -3.9747286
# 0 -2.9098263
# 0 -3.620987
# 0 -3.8191895
# 0 -3.971662
# 0 -3.844112
# 0 -3.8739634
# 0 -2.6712217
# 0 -3.8738399
# 0 -3.910718
# 0 -3.1549206
# 0 -3.6134596
# 0 -3.7485743
# 0 -3.854948
# 0 -3.9577498
# 0 -4.027182
# 0 -3.8691196
# 0 -3.713459
# 0 -3.8251586
# 0 -3.8383594
# 0 -3.895092
# 0 -3.8115878
# 0 -3.974122
# 0 -3.2811198
# 0 -4.0744767
# 0 -3.4083524
# 0 -3.5961595
# 0 -3.2610173
# 0 -3.020105
# 0 -5.070881
# 0 -3.6884494
# 0 -3.953363
# 0 -3.3901348
# 0 -4.0399117
# 0 -3.3701348
# 0 -5.042525
# 0 -3.3425212
# 0 -3.1979423
# 0 -3.9007325
# 0 -3.4515057
# 0 -4.005899
# 0 -3.6377544
# 0 -3.5571995
# 0 -3.397081
# 0 -3.5330887
# 0 -3.341989
# 0 -3.9394078
# 0 -3.8895407
# 0 -3.885519
# 0 -3.9270487
# 0 -3.855713
# 0 -3.8824306
# 0 -3.3631172
# 0 -4.038524
# 0 -3.558618
# 0 -2.5818381
# 0 -3.2360935
# 0 -3.198852
# 0 -4.007921
# 0 -3.199565
# 0 -3.30161
# 0 -2.866458
# 0 -3.3607326
# 0 -3.4798293
# 0 -3.699686
# 1 -3.3507257
# 0 -3.3609457
# 0 -13.620244
# 0 -3.7639623
# 0 -4.4424567
# 0 -4.6502557
# 0 -3.88724
# 0 -3.8515682
# 0 -2.9497533
# 0 -3.895749
# 0 -4.0976977
# 0 -3.7412329
# 0 -3.0289335
# 0 -3.4479003
# 0 -3.9165182
# 0 -3.7482767
# 0 -3.1710439
# 0 -4.0093255
# 0 -3.6656055
# 0 -4.461963
# 0 -3.4240718
# 0 -3.1507754
# 0 -3.124156
# 0 -3.6441436
# 0 -3.6002355
# 0 -3.2070327
# 0 -3.810402
# 0 -3.9054742
# 0 -3.2080507
# 0 -3.5282073
# 0 -3.7358003
# 0 -3.2528949
# 0 -3.6102672
# 0 -3.2085366
# 0 -3.8831196
# 0 -3.3676367
# 0 -3.7453432
# 0 -4.3351827
# 0 -3.2436066
# 0 -3.1327348
# 0 -3.3387837
# 0 -3.0605845
# 0 -3.796866
# 0 -3.0066595
# 0 -3.0004091
# 0 -4.5086102
# 0 -3.3384886
# 0 -3.5383706
# 0 -3.182232
# 1 -3.53963
# 0 -3.2814975
# 0 -4.503121
# 0 -3.3595247
# 0 -3.2512732
# 0 -3.4568934
# 0 -3.2344446
# 1 -3.9218655
# 1 -3.9234667
# 0 -4.079109
# 0 -4.49456
# 0 -4.6308064
# 0 -3.7389064
# 0 -4.5044875
# 0 -4.050423
# 0 -2.9670777
# 0 -3.9402423
# 0 -3.911367
# 0 -3.0800705
# 0 -3.1552134
# 0 -3.8293738
# 0 -4.49687
# 0 -3.1646848
# 0 -3.6512737
# 0 -3.7651248
# 0 -3.5863705
# 0 -2.6314588
# 0 -4.0654545
# 0 -4.0937815
# 0 -4.075308
# 0 -3.6905642
# 0 -4.0311494
# 0 -3.2668257
# 0 -3.2498717
# 0 -4.090519
# 0 -2.9136386
# 0 -3.4880548
# 0 -3.408688
# 0 -3.7570114
# 0 -4.025639
# 0 -4.0047655
# 0 -3.4038038
# 1 -4.9845424
# 0 -5.0120454
# 0 -5.330651
# 0 -3.7808285
# 0 -2.5352292
# 0 -3.2784595
# 0 -3.401764
# 0 -3.300414
# 0 -3.927352
# 0 -3.8240523
# 0 -3.8461447
# 0 -3.7362728
# 0 -3.8523097
# 0 -3.6252794
# 0 -3.5779939
# 0 -3.2094507
# 0 -2.6838517
# 0 -4.236764
# 0 -3.6907802
# 0 -3.9460945
# 0 -3.6478233
# 0 -3.340743
# 0 -3.6481133
# 0 -3.3083344
# 0 -3.4157677
# 0 -3.4622202
# 0 -3.1132483
# 0 -3.7086163
# 0 -3.7860384
# 0 -3.604743
# 0 -3.828164
# 0 -3.0988936
# 0 -3.9412065
# 1 -3.3998895
# 0 -4.7263026
# 0 -5.088018
# 0 -3.406242
# 0 -3.0859604
# 0 -3.4428458
# 0 -3.897676
# 0 -4.3514047
# 0 -3.9473963
# 0 -3.5847998
# 0 -3.756619
# 0 -3.630898
# 0 -3.0241747
# 0 -3.5362039
# 0 -3.8908691
# 0 -3.5197773
# 0 -3.1178527
# 0 -3.5315661
# 0 -3.4587626
# 0 -3.5900922
# 0 -4.2328057
# 0 -3.5926847
# 0 -3.8305416
# 0 -3.9855413
# 0 -3.8484344
# 0 -3.974814
# 0 -3.9539046
# 0 -3.8245487
# 0 -2.7358088
# 0 -3.966497
# 0 -2.245103
# 0 -2.612399
# 0 -3.925387
# 0 -3.9342308
# 0 -3.6308985
# 0 -3.4163036
# 0 -3.7397346
# 0 -3.8571215
# 0 -3.9231458
# 0 -4.0290246
# 0 -3.314515
# 0 -3.1929913
# 0 -3.9166932
# 0 -4.640101
# 0 -4.241748
# 0 -4.008877
# 0 -3.6533728
# 0 -3.5643368
# 0 -3.4197493
# 0 -2.8671517
# 0 -3.4747763
# 0 -3.706758
# 0 -3.3948112
# 0 -3.5149145
# 0 -3.395187
# 0 -4.3478003
# 0 -6.3448415
# 0 -2.6799707
# 0 -3.0854788
# 0 -3.134121
# 0 -3.0611935
# 0 -3.6407132
# 0 -4.4433928
# 0 -4.55382
# 1 -3.2153525
# 0 -4.418233
# 0 -4.043435
# 0 -3.3483157
# 0 -3.670095
# 0 -3.9003472
# 0 -3.9375834
# 0 -4.4748263
# 0 -3.5954137
# 0 -3.7117915
# 1 -3.3870988
# 1 -3.9082346
# 0 -1.7570919
# 0 -1.9963583
# 0 -3.5038528
# 0 -3.8864012
# 0 -6.3304915
# 0 -3.3262405
# 0 -3.902166
# 0 -4.3613067
# 0 -3.025299
# 0 -3.7362761
# 0 -3.6337914
# 1 -3.4067335
# 0 -3.3555765
# 0 -4.4891634
# 0 -3.5488195
# 0 -3.9869556
# 0 -3.6612663
# 0 -3.8660831
# 0 -3.4087086
# 0 -3.880199
# 0 -2.8303976
# 0 -3.4214468
# 0 -3.5180726
# 0 -3.5107207
# 0 -4.371101
# 0 -4.420544
# 0 -3.8367515
# 0 -3.6213593
# 0 -3.4390726
# 0 -3.533084
# 0 -3.7732396
# 0 -3.5389514
# 0 -3.6056314
# 0 -2.8818684
# 0 -2.9083195
# 1 -3.3004131
# 0 -3.5943294
# 0 -3.1127238
# 0 -3.203876
# 0 -3.2891135
# 0 -3.558148
# 0 -6.902334
# 0 -6.8115973
# 0 -3.7963338
# 0 -3.8242512
# 0 -4.894755
# 0 -3.7253838
# 0 -3.4405503
# 0 -3.2792277
# 0 -3.8078117
# 0 -3.7720613
# 0 -3.114656
# 0 -3.5847926
# 0 -3.6175017
# 0 -3.692204
# 0 -2.8581567
# 0 -3.6423273
# 0 -3.9022994
# 0 -3.3635535
# 0 -2.5848608
# 0 -4.034387
# 0 -3.5022163
# 0 -3.5939674
# 0 -3.1016335
# 0 -3.8372922
# 0 -3.3629208
# 0 -3.2326074
# 0 -3.6570034
# 0 -3.9208293
# 0 -3.3608708
# 0 -3.6660233
# 0 -3.778098
# 0 -3.2093678
# 0 -3.1135015
# 0 -4.370487
# 0 -2.5024834
# 0 -6.4560766
# 0 -3.9317498
# 0 -3.9017854
# 0 -3.8747377
# 0 -3.8850965
# 0 -3.8022923
# 0 -3.5712194
# 0 -4.395169
# 0 -3.6398878
# 0 -3.0276842
# 0 -4.056282
# 0 -3.4646559
# 1 -3.8385391
# 0 -3.6830535
# 0 -3.7096038
# 0 -3.729169
# 0 -3.1727123
# 0 -3.2587495
# 0 -3.0299082
# 0 -3.3754992
# 0 -3.2174015
# 0 -3.9887853
# 0 -3.6666632
# 0 -3.6997914
# 0 -3.6510525
# 0 -4.0817385
# 0 -3.5125494
# 0 -3.5413241
# 0 -3.73954
# 0 -4.352121
# 0 -3.3769474
# 0 -4.071712
# 0 -3.660336
# 0 -3.812591
# 1 -4.310979
# 0 -3.8051524
# 0 -3.3855772
# 0 -3.1035686
# 0 -3.5512404
# 0 -3.8946252
# 0 -3.403552
# 0 -2.6011214
# 0 -3.543171
# 0 -3.2810879
# 0 -3.456883
# 0 -2.9383059
# 0 -3.7954955
# 0 -3.817287
# 0 -3.3830605
# 0 -3.9924803
# 0 -3.6808739
# 0 -3.8653188
# 0 -3.8461995
# 1 -3.4882102
# 0 -3.9709344
# 0 -3.4956079
# 0 -3.6000133
# 0 -2.5026808
# 0 -3.4485054
# 0 -3.8298697
# 0 -3.1423569
# 0 -3.4350743
# 0 -3.4521332
# 0 -3.4174094
# 0 -3.9015656
# 0 -5.4416413
# 0 -4.133873
# 0 -3.44806
# 0 -3.8370957
# 0 -4.6774817
# 0 -4.5134397
# 0 -3.3183112
# 0 -3.7952752
# 0 -4.2642155
# 0 -3.2583065
# 0 -3.9210482
# 0 -3.8792682
# 0 -3.5943456
# 0 -3.5606236
# 0 -3.6220646
# 0 -3.026321
# 0 -4.0014935
# 0 -2.9903326
# 0 -3.0956678
# 0 -3.400608
# 0 -3.1463585
# 0 -3.356997
# 0 -3.3371334
# 0 -3.8278956
# 0 -3.688674
# 0 -3.7493138
# 0 -3.0541644
# 0 -4.381023
# 0 -3.2553334
# 0 -3.290381
# 0 -2.8491054
# 0 -2.9195275
# 0 -3.9862046
# 0 -3.778924
# 0 -2.8843274
# 0 -2.6915216
# 0 -3.2579312
# 0 -2.6690893
# 0 -4.4990067
# 0 -4.7662225
# 0 -4.877992
# 0 -4.8922515
# 0 -4.1876187
# 0 -2.9099045
# 0 -3.1215854
# 0 -3.740882
# 0 -3.3766093
# 0 -3.5166988
# 0 -4.173775
# 0 -3.3856058
# 0 -2.8793287
# 0 -3.8614836
# 0 -3.9613876
# 0 -2.9996881
# 0 -3.8453293
# 0 -3.7364454
# 0 -3.3372755
# 0 -3.584681
# 0 -3.709115
# 0 -4.391963
# 0 -3.4562387
# 0 -3.5666304
# 0 -3.6195054
# 0 -4.3592243
# 0 -2.4089766
# 0 -3.0885272
# 0 -3.6036954
# 0 -3.11978
# 0 -3.230742
# 0 -3.511026
# 0 -3.2924829
# 0 -4.6112123
# 0 -3.2956276
# 0 -3.1982007
# 0 -3.7350955
# 0 -3.4008765
# 1 -3.3529854
# 0 -3.2089133
# 1 -3.4182425
# 0 -3.9621043
# 0 -3.6018896
# 0 -5.970449
# 0 -3.0978532
# 0 -2.665893
# 0 -2.8042693
# 0 -3.7707982
# 0 -3.2327456
# 0 -3.4795356
# 0 -3.30156
# 0 -2.5317874
# 0 -4.841123
# 0 -3.6751957
# 0 -3.5358171
# 0 -3.614449
# 0 -3.4677901
# 0 -3.3024292
# 0 -3.4592566
# 0 -3.5149612
# 0 -3.2768188
# 0 -3.8264155
# 0 -3.6975107
# 0 -3.58983
# 0 -2.9606018
# 0 -3.8424764
# 1 -6.354184
# 0 -3.8715014
# 0 -3.3072777
# 0 -3.5107894
# 0 -4.023087
# 0 -3.431017
# 0 -3.927343
# 0 -3.4615355
# 0 -3.7498832
# 0 -3.653387
# 0 -3.740871
# 0 -3.7659898
# 0 -3.2360258
# 0 -2.9677973
# 1 -2.8974967
# 0 -3.9322658
# 0 -3.9263864
# 0 -6.47658
# 0 -3.6593566
# 0 -3.8033962
# 0 -3.8598123
# 0 -3.738326
# 0 -3.6391091
# 0 -3.8690367
# 0 -3.4465308
# 0 -3.5360017
# 0 -3.139989
# 0 -3.3488765
# 0 -2.9404216
# 0 -3.657216
# 0 -3.8231544
# 0 -3.654242
# 0 -2.8418498
# 0 -3.764598
# 0 -3.5966358
# 0 -3.943097
# 0 -2.9754357
# 1 -3.591041
# 0 -3.9102554
# 0 -4.6482754
# 0 -3.1611543
# 0 -3.088396
# 0 -3.0508223
# 0 -3.7218952
# 0 -3.4199586
# 0 -3.4807096
# 0 -3.4887075
# 0 -3.7892447
# 0 -3.2794342
# 0 -6.0268884
# 0 -3.089366
# 0 -3.2470632
# 0 -3.9421797
# 0 -3.4515157
# 0 -3.3446808
# 1 -3.2909255
# 0 -3.8647342
# 0 -3.8135462
# 0 -3.3667555
# 1 -4.0819964
# 1 -3.2404761
# 0 -3.2043
# 1 -3.1883545
# 0 -3.1896925
# 0 -3.177804
# 1 -3.1262107
# 0 -3.8101625
# 0 -4.234319
# 0 -3.926777
# 0 -3.5110025
# 0 -3.1908803
# 0 -3.8829722
# 0 -4.247684
# 0 -5.082919
# 0 -4.500266
# 0 -3.7442527
# 0 -3.9534378
# 0 -3.9230666
# 0 -3.7598472
# 0 -3.6344056
# 0 -2.622229
# 0 -4.361979
# 0 -3.9983563
# 0 -3.6417193
# 0 -3.2582765
# 0 -3.1691318
# 0 -4.143815
# 0 -3.9843502
# 0 -3.6648989
# 0 -3.3629923
# 0 -3.5661097
# 0 -3.8162246
# 0 -3.6487799
# 0 -4.4549384
# 0 -3.4507422
# 0 -3.446271
# 0 -3.2827806
# 0 -3.8653736
# 0 -3.672933
# 0 -3.1789622
# 0 -3.8384356
# 0 -3.8606887
# 0 -3.7516556
# 0 -3.4545937
# 0 -3.8663898
# 0 -3.9404135
# 0 -3.5907316
# 0 -3.5931034
# 0 -2.4449859
# 0 -3.5482097
# 0 -3.5650883
# 0 -3.2543383
# 0 -3.4984365
# 0 -2.9539037
# 0 -3.66121
# 0 -2.6800318
# 0 -3.6740513
# 0 -2.7783513
# 0 -3.41604
# 0 -3.0739465
# 0 -3.7542105
# 0 -3.9164133
# 0 -1.8165408
# 0 -3.3057609
# 0 -3.2554555
# 0 -2.9514513
# 0 -2.5553083
# 0 -4.0070977
# 0 -4.103506
# 0 -3.8262634
# 0 -2.4269867
# 0 -4.0271573
# 0 -3.0938125
# 0 -2.9758258
# 0 -3.798612
# 0 -3.7565513
# 0 -4.1128798
# 0 -4.0159507
# 0 -4.117659
# 0 -4.023863
# 0 -3.659688
# 0 -3.8198624
# 0 -3.9126978
# 0 -2.985931
# 0 -4.257774
# 0 -3.1488657
# 0 -3.9817133
# 0 -3.5331707
# 0 -3.6667442
# 0 -3.5452933
# 0 -3.0213752
# 0 -4.7941055
# 0 -2.9809175
# 0 -4.0909677
# 0 -3.1180048
# 0 -3.749981
# 0 -3.5879903
# 0 -3.8174
# 0 -3.4779153
# 0 -2.937934
# 0 -3.5364294
# 0 -3.751596
# 0 -3.868322
# 0 -3.147304
# 0 -3.910368
# 0 -3.8419523
# 0 -3.7829537
# 0 -3.1188364
# 0 -3.0207996
# 0 -3.243074
# 0 -3.864977
# 0 -3.7673721
# 0 -3.4325504
# 0 -3.1411052
# 0 -3.2579265
# 0 -3.511467
# 0 -3.430756
# 0 -3.0444999
# 0 -3.4747658
# 0 -3.457531
# 0 -3.3012328
# 0 -4.1308885
# 0 -3.232121
# 0 -4.212771
# 0 -3.9348521
# 0 -3.3254056
# 0 -3.2242794
# 0 -3.527865
# 0 -2.8109255
# 0 -2.9833775
# 0 -2.9308562
# 0 -4.008135
# 0 -3.4948268
# 0 -3.0629892
# 0 -4.2141457
# 0 -3.8098464
# 0 -4.994029
# 0 -3.7706861
# 0 -3.236833
# 0 -3.3215404
# 0 -3.7586484
# 1 -3.7027001
# 0 -4.2746487
# 0 -4.0152755
# 0 -3.9644146
# 0 -4.1356483
# 0 -5.171131
# 0 -3.2157345
# 0 -2.979846
# 0 -3.53727
# 0 -3.1061974
# 0 -4.57616
# 0 -3.4149504
# 0 -3.8542151
# 0 -3.3502483
# 0 -2.6217217
# 0 -4.0598516
# 0 -3.3625145
# 0 -4.0503855
# 0 -2.7699409
# 0 -3.326311
# 0 -3.7004309
# 0 -3.542688
# 0 -2.9980726
# 0 -3.054625
# 0 -2.3706656
# 0 -3.9482765
# 0 -4.0684323
# 0 -3.7568064
# 0 -3.3294826
# 0 -3.940239
# 0 -4.156776
# 0 -3.4286141
# 0 -2.627531
# 0 -2.9577336
# 0 -3.5900707
# 0 -2.9359236
# 0 -2.3495603
# 0 -3.7353158
# 0 -2.9861016
# 0 -3.2643394
# 0 -3.8712459
# 0 -3.7961931
# 0 -4.0602202
# 0 -4.097983
# 0 -4.0294375
# 0 -3.2938585
# 0 -3.3304644
# 0 -3.3550377
# 0 -3.989089
# 0 -3.7619076
# 0 -3.718845
# 0 -3.1013184
# 0 -3.2077188
# 0 -3.8095012
# 0 -3.280229
# 0 -3.3344064
# 0 -3.272111
# 0 -2.6375642
# 0 -4.3822975
# 1 -3.3637252
# 0 -4.063663
# 0 -4.10042
# 0 -3.9777265
# 0 -2.929659
# 0 -3.8554478
# 0 -3.5067964
# 0 -3.1535635
# 0 -3.1304932
# 0 -3.762432
# 0 -3.8300152
# 0 -3.5591536
# 0 -3.5134797
# 0 -3.555698
# 0 -3.5594616
# 0 -3.7708325
# 0 -3.737618
# 0 -3.517634
# 0 -3.599154
# 0 -3.9674425
# 0 -3.784937
# 0 -3.3821344
# 0 -3.371544
# 1 -3.9527507
# 1 -3.08146
# 0 -2.767908
# 0 -3.2702699
# 0 -3.0352454
# 0 -3.4742184
# 0 -2.5590386
# 0 -2.4760728
# 0 -2.6591897
# 0 -3.6606746
# 0 -4.066373
# 0 -4.0054164
# 0 -3.5332923
# 0 -3.5809755
# 0 -3.4535117
# 0 -3.4543839
# 0 -3.3135095
# 0 -3.7924275
# 0 -3.9043097
# 0 -3.626152
# 0 -1.8410615
# 0 -3.70331
# 0 -3.4334621
# 0 -3.9247613
# 0 -3.0365348
# 0 -3.4133306
# 0 -3.8833437
# 0 -4.221507
# 0 -3.183404
# 0 -4.20428

# %%
import torch
from torch_geometric.data import DataLoader
import torch.optim as optim
import torch.nn.functional as F
from gnn import GNN, GNN_noBN
from sklearn.metrics import roc_auc_score

from tqdm import tqdm
import argparse
import time
import numpy as np

### importing OGB
from ogb.graphproppred import PygGraphPropPredDataset, Evaluator

def eval(model, device, loader, evaluator):
    model.eval()
    y_true = []
    y_pred = []
    for step, batch in enumerate(loader):
        batch = batch.to(device)
        print(batch)
        with torch.no_grad():
            pred = model(batch)
        y_true.append(batch.y.view(pred.shape).detach().cpu())
        y_pred.append(pred.detach().cpu())

    y_true = torch.cat(y_true, dim = 0).numpy()
    y_pred = torch.cat(y_pred, dim = 0).numpy()
    
    return y_true, y_pred


device = torch.device("cpu")
dataset = PygGraphPropPredDataset(name = 'ogbg-molhiv')
split_idx = dataset.get_idx_split()
evaluator = Evaluator('ogbg-molhiv')
test_loader = DataLoader(dataset[split_idx["test"][0:1]], batch_size=1, shuffle=False, num_workers = 1)

model = torch.load('gin_ep1_dim100.pt')
model_noBN = GNN_noBN(gnn_type = 'gin', num_tasks = 1, num_layer = 5, emb_dim = 100, drop_ratio = 0.5, virtual_node = False).to(device)
print('Evaluating...')


ytrue, ypred = eval(model, device, test_loader, evaluator)
print(ypred)



model_noBN.training=False
model_noBN.eval()
model.training = False
bn_eps = 0.00001
model_noBN.state_dict()['gnn_node_noBN.atom_encoder.atom_embedding_list.0.weight'].copy_( model.state_dict()['gnn_node.atom_encoder.atom_embedding_list.0.weight'] )
model_noBN.state_dict()['gnn_node_noBN.atom_encoder.atom_embedding_list.1.weight'].copy_( model.state_dict()['gnn_node.atom_encoder.atom_embedding_list.1.weight'] )
model_noBN.state_dict()['gnn_node_noBN.atom_encoder.atom_embedding_list.2.weight'].copy_( model.state_dict()['gnn_node.atom_encoder.atom_embedding_list.2.weight'] )
model_noBN.state_dict()['gnn_node_noBN.atom_encoder.atom_embedding_list.3.weight'].copy_( model.state_dict()['gnn_node.atom_encoder.atom_embedding_list.3.weight'] )
model_noBN.state_dict()['gnn_node_noBN.atom_encoder.atom_embedding_list.4.weight'].copy_( model.state_dict()['gnn_node.atom_encoder.atom_embedding_list.4.weight'] )
model_noBN.state_dict()['gnn_node_noBN.atom_encoder.atom_embedding_list.5.weight'].copy_( model.state_dict()['gnn_node.atom_encoder.atom_embedding_list.5.weight'] )
model_noBN.state_dict()['gnn_node_noBN.atom_encoder.atom_embedding_list.6.weight'].copy_( model.state_dict()['gnn_node.atom_encoder.atom_embedding_list.6.weight'] )
model_noBN.state_dict()['gnn_node_noBN.atom_encoder.atom_embedding_list.7.weight'].copy_( model.state_dict()['gnn_node.atom_encoder.atom_embedding_list.7.weight'] )
model_noBN.state_dict()['gnn_node_noBN.atom_encoder.atom_embedding_list.8.weight'].copy_( model.state_dict()['gnn_node.atom_encoder.atom_embedding_list.8.weight'] )
model_noBN.state_dict()['gnn_node_noBN.convs.0.eps'].copy_( model.state_dict()['gnn_node.convs.0.eps'] )

MLP_weight = model.state_dict()['gnn_node.convs.0.mlp.0.weight']
MLP_bias = model.state_dict()['gnn_node.convs.0.mlp.0.bias']
running_mean = model.state_dict()['gnn_node.convs.0.mlp.1.running_mean']
running_var = model.state_dict()['gnn_node.convs.0.mlp.1.running_var']
bn_weight = model.state_dict()['gnn_node.convs.0.mlp.1.weight']
bn_bias = model.state_dict()['gnn_node.convs.0.mlp.1.bias']

MLP_weight = MLP_weight.t()
MLP_weight = (torch.div(MLP_weight, torch.sqrt(running_var + bn_eps)) * bn_weight).t()
MLP_bias = torch.div((MLP_bias - running_mean), torch.sqrt(running_var + bn_eps)) * bn_weight + bn_bias

model_noBN.state_dict()['gnn_node_noBN.convs.0.mlp.0.weight'].copy_(MLP_weight)
model_noBN.state_dict()['gnn_node_noBN.convs.0.mlp.0.bias'].copy_(MLP_bias)

MLP_weight = model.state_dict()['gnn_node.convs.0.mlp.3.weight']
MLP_bias = model.state_dict()['gnn_node.convs.0.mlp.3.bias']
running_mean = model.state_dict()['gnn_node.batch_norms.0.running_mean']
running_var = model.state_dict()['gnn_node.batch_norms.0.running_var']
bn_weight = model.state_dict()['gnn_node.batch_norms.0.weight']
bn_bias = model.state_dict()['gnn_node.batch_norms.0.bias']

MLP_weight = MLP_weight.t()
MLP_weight = (torch.div(MLP_weight, torch.sqrt(running_var + bn_eps)) * bn_weight).t()
MLP_bias = torch.div((MLP_bias - running_mean), torch.sqrt(running_var + bn_eps)) * bn_weight + bn_bias

model_noBN.state_dict()['gnn_node_noBN.convs.0.mlp.2.weight'].copy_(MLP_weight)
model_noBN.state_dict()['gnn_node_noBN.convs.0.mlp.2.bias'].copy_(MLP_bias)

model_noBN.state_dict()['gnn_node_noBN.convs.0.bond_encoder.bond_embedding_list.0.weight'].copy_(model.state_dict()['gnn_node.convs.0.bond_encoder.bond_embedding_list.0.weight'])
model_noBN.state_dict()['gnn_node_noBN.convs.0.bond_encoder.bond_embedding_list.1.weight'].copy_(model.state_dict()['gnn_node.convs.0.bond_encoder.bond_embedding_list.1.weight'])
model_noBN.state_dict()['gnn_node_noBN.convs.0.bond_encoder.bond_embedding_list.2.weight'].copy_(model.state_dict()['gnn_node.convs.0.bond_encoder.bond_embedding_list.2.weight'])
model_noBN.state_dict()['gnn_node_noBN.convs.1.eps'].copy_( model.state_dict()['gnn_node.convs.1.eps'] )

MLP_weight = model.state_dict()['gnn_node.convs.1.mlp.0.weight']
MLP_bias = model.state_dict()['gnn_node.convs.1.mlp.0.bias']
running_mean = model.state_dict()['gnn_node.convs.1.mlp.1.running_mean']
running_var = model.state_dict()['gnn_node.convs.1.mlp.1.running_var']
bn_weight = model.state_dict()['gnn_node.convs.1.mlp.1.weight']
bn_bias = model.state_dict()['gnn_node.convs.1.mlp.1.bias']

MLP_weight = MLP_weight.t()
MLP_weight = (torch.div(MLP_weight, torch.sqrt(running_var + bn_eps)) * bn_weight).t()
MLP_bias = torch.div((MLP_bias - running_mean), torch.sqrt(running_var + bn_eps)) * bn_weight + bn_bias

model_noBN.state_dict()['gnn_node_noBN.convs.1.mlp.0.weight'].copy_(MLP_weight)
model_noBN.state_dict()['gnn_node_noBN.convs.1.mlp.0.bias'].copy_(MLP_bias)

MLP_weight = model.state_dict()['gnn_node.convs.1.mlp.3.weight']
MLP_bias = model.state_dict()['gnn_node.convs.1.mlp.3.bias']
running_mean = model.state_dict()['gnn_node.batch_norms.1.running_mean']
running_var = model.state_dict()['gnn_node.batch_norms.1.running_var']
bn_weight = model.state_dict()['gnn_node.batch_norms.1.weight']
bn_bias = model.state_dict()['gnn_node.batch_norms.1.bias']

MLP_weight = MLP_weight.t()
MLP_weight = (torch.div(MLP_weight, torch.sqrt(running_var + bn_eps)) * bn_weight).t()
MLP_bias = torch.div((MLP_bias - running_mean), torch.sqrt(running_var + bn_eps)) * bn_weight + bn_bias

model_noBN.state_dict()['gnn_node_noBN.convs.1.mlp.2.weight'].copy_(MLP_weight)
model_noBN.state_dict()['gnn_node_noBN.convs.1.mlp.2.bias'].copy_(MLP_bias)

model_noBN.state_dict()['gnn_node_noBN.convs.1.bond_encoder.bond_embedding_list.0.weight'].copy_( model.state_dict()['gnn_node.convs.1.bond_encoder.bond_embedding_list.0.weight'] )
model_noBN.state_dict()['gnn_node_noBN.convs.1.bond_encoder.bond_embedding_list.1.weight'].copy_( model.state_dict()['gnn_node.convs.1.bond_encoder.bond_embedding_list.1.weight'] )
model_noBN.state_dict()['gnn_node_noBN.convs.1.bond_encoder.bond_embedding_list.2.weight'].copy_( model.state_dict()['gnn_node.convs.1.bond_encoder.bond_embedding_list.2.weight'] )
model_noBN.state_dict()['gnn_node_noBN.convs.2.eps'].copy_( model.state_dict()['gnn_node.convs.2.eps'] )

MLP_weight = model.state_dict()['gnn_node.convs.2.mlp.0.weight']
MLP_bias = model.state_dict()['gnn_node.convs.2.mlp.0.bias']
running_mean = model.state_dict()['gnn_node.convs.2.mlp.1.running_mean']
running_var = model.state_dict()['gnn_node.convs.2.mlp.1.running_var']
bn_weight = model.state_dict()['gnn_node.convs.2.mlp.1.weight']
bn_bias = model.state_dict()['gnn_node.convs.2.mlp.1.bias']

MLP_weight = MLP_weight.t()
MLP_weight = (torch.div(MLP_weight, torch.sqrt(running_var + bn_eps)) * bn_weight).t()
MLP_bias = torch.div((MLP_bias - running_mean), torch.sqrt(running_var + bn_eps)) * bn_weight + bn_bias

model_noBN.state_dict()['gnn_node_noBN.convs.2.mlp.0.weight'].copy_(MLP_weight)
model_noBN.state_dict()['gnn_node_noBN.convs.2.mlp.0.bias'].copy_(MLP_bias)

MLP_weight = model.state_dict()['gnn_node.convs.2.mlp.3.weight']
MLP_bias = model.state_dict()['gnn_node.convs.2.mlp.3.bias']
running_mean = model.state_dict()['gnn_node.batch_norms.2.running_mean']
running_var = model.state_dict()['gnn_node.batch_norms.2.running_var']
bn_weight = model.state_dict()['gnn_node.batch_norms.2.weight']
bn_bias = model.state_dict()['gnn_node.batch_norms.2.bias']

MLP_weight = MLP_weight.t()
MLP_weight = (torch.div(MLP_weight, torch.sqrt(running_var + bn_eps)) * bn_weight).t()
MLP_bias = torch.div((MLP_bias - running_mean), torch.sqrt(running_var + bn_eps)) * bn_weight + bn_bias

model_noBN.state_dict()['gnn_node_noBN.convs.2.mlp.2.weight'].copy_(MLP_weight)
model_noBN.state_dict()['gnn_node_noBN.convs.2.mlp.2.bias'].copy_(MLP_bias)

model_noBN.state_dict()['gnn_node_noBN.convs.2.bond_encoder.bond_embedding_list.0.weight'].copy_( model.state_dict()['gnn_node.convs.2.bond_encoder.bond_embedding_list.0.weight'] )
model_noBN.state_dict()['gnn_node_noBN.convs.2.bond_encoder.bond_embedding_list.1.weight'].copy_( model.state_dict()['gnn_node.convs.2.bond_encoder.bond_embedding_list.1.weight'] )
model_noBN.state_dict()['gnn_node_noBN.convs.2.bond_encoder.bond_embedding_list.2.weight'].copy_( model.state_dict()['gnn_node.convs.2.bond_encoder.bond_embedding_list.2.weight'] )
model_noBN.state_dict()['gnn_node_noBN.convs.3.eps'].copy_( model.state_dict()['gnn_node.convs.3.eps'] )


MLP_weight = model.state_dict()['gnn_node.convs.3.mlp.0.weight']
MLP_bias = model.state_dict()['gnn_node.convs.3.mlp.0.bias']
running_mean = model.state_dict()['gnn_node.convs.3.mlp.1.running_mean']
running_var = model.state_dict()['gnn_node.convs.3.mlp.1.running_var']
bn_weight = model.state_dict()['gnn_node.convs.3.mlp.1.weight']
bn_bias = model.state_dict()['gnn_node.convs.3.mlp.1.bias']

MLP_weight = MLP_weight.t()
MLP_weight = (torch.div(MLP_weight, torch.sqrt(running_var + bn_eps)) * bn_weight).t()
MLP_bias = torch.div((MLP_bias - running_mean), torch.sqrt(running_var + bn_eps)) * bn_weight + bn_bias

model_noBN.state_dict()['gnn_node_noBN.convs.3.mlp.0.weight'].copy_(MLP_weight)
model_noBN.state_dict()['gnn_node_noBN.convs.3.mlp.0.bias'].copy_(MLP_bias)

MLP_weight = model.state_dict()['gnn_node.convs.3.mlp.3.weight']
MLP_bias = model.state_dict()['gnn_node.convs.3.mlp.3.bias']
running_mean = model.state_dict()['gnn_node.batch_norms.3.running_mean']
running_var = model.state_dict()['gnn_node.batch_norms.3.running_var']
bn_weight = model.state_dict()['gnn_node.batch_norms.3.weight']
bn_bias = model.state_dict()['gnn_node.batch_norms.3.bias']

MLP_weight = MLP_weight.t()
MLP_weight = (torch.div(MLP_weight, torch.sqrt(running_var + bn_eps)) * bn_weight).t()
MLP_bias = torch.div((MLP_bias - running_mean), torch.sqrt(running_var + bn_eps)) * bn_weight + bn_bias

model_noBN.state_dict()['gnn_node_noBN.convs.3.mlp.2.weight'].copy_(MLP_weight)
model_noBN.state_dict()['gnn_node_noBN.convs.3.mlp.2.bias'].copy_(MLP_bias)

model_noBN.state_dict()['gnn_node_noBN.convs.3.bond_encoder.bond_embedding_list.0.weight'].copy_( model.state_dict()['gnn_node.convs.3.bond_encoder.bond_embedding_list.0.weight'] )
model_noBN.state_dict()['gnn_node_noBN.convs.3.bond_encoder.bond_embedding_list.1.weight'].copy_( model.state_dict()['gnn_node.convs.3.bond_encoder.bond_embedding_list.1.weight'] )
model_noBN.state_dict()['gnn_node_noBN.convs.3.bond_encoder.bond_embedding_list.2.weight'].copy_( model.state_dict()['gnn_node.convs.3.bond_encoder.bond_embedding_list.2.weight'] )
model_noBN.state_dict()['gnn_node_noBN.convs.4.eps'].copy_( model.state_dict()['gnn_node.convs.4.eps'] )

MLP_weight = model.state_dict()['gnn_node.convs.4.mlp.0.weight']
MLP_bias = model.state_dict()['gnn_node.convs.4.mlp.0.bias']
running_mean = model.state_dict()['gnn_node.convs.4.mlp.1.running_mean']
running_var = model.state_dict()['gnn_node.convs.4.mlp.1.running_var']
bn_weight = model.state_dict()['gnn_node.convs.4.mlp.1.weight']
bn_bias = model.state_dict()['gnn_node.convs.4.mlp.1.bias']

MLP_weight = MLP_weight.t()
MLP_weight = (torch.div(MLP_weight, torch.sqrt(running_var + bn_eps)) * bn_weight).t()
MLP_bias = torch.div((MLP_bias - running_mean), torch.sqrt(running_var + bn_eps)) * bn_weight + bn_bias

model_noBN.state_dict()['gnn_node_noBN.convs.4.mlp.0.weight'].copy_(MLP_weight)
model_noBN.state_dict()['gnn_node_noBN.convs.4.mlp.0.bias'].copy_(MLP_bias)

MLP_weight = model.state_dict()['gnn_node.convs.4.mlp.3.weight']
MLP_bias = model.state_dict()['gnn_node.convs.4.mlp.3.bias']
running_mean = model.state_dict()['gnn_node.batch_norms.4.running_mean']
running_var = model.state_dict()['gnn_node.batch_norms.4.running_var']
bn_weight = model.state_dict()['gnn_node.batch_norms.4.weight']
bn_bias = model.state_dict()['gnn_node.batch_norms.4.bias']

MLP_weight = MLP_weight.t()
MLP_weight = (torch.div(MLP_weight, torch.sqrt(running_var + bn_eps)) * bn_weight).t()
MLP_bias = torch.div((MLP_bias - running_mean), torch.sqrt(running_var + bn_eps)) * bn_weight + bn_bias

model_noBN.state_dict()['gnn_node_noBN.convs.4.mlp.2.weight'].copy_(MLP_weight)
model_noBN.state_dict()['gnn_node_noBN.convs.4.mlp.2.bias'].copy_(MLP_bias)

model_noBN.state_dict()['gnn_node_noBN.convs.4.bond_encoder.bond_embedding_list.0.weight'].copy_( model.state_dict()['gnn_node.convs.4.bond_encoder.bond_embedding_list.0.weight'] )
model_noBN.state_dict()['gnn_node_noBN.convs.4.bond_encoder.bond_embedding_list.1.weight'].copy_( model.state_dict()['gnn_node.convs.4.bond_encoder.bond_embedding_list.1.weight'] )
model_noBN.state_dict()['gnn_node_noBN.convs.4.bond_encoder.bond_embedding_list.2.weight'].copy_( model.state_dict()['gnn_node.convs.4.bond_encoder.bond_embedding_list.2.weight'] )
model_noBN.state_dict()['graph_pred_linear.weight'].copy_( model.state_dict()['graph_pred_linear.weight'] )
model_noBN.state_dict()['graph_pred_linear.bias'].copy_( model.state_dict()['graph_pred_linear.bias'] )



ytrue, ypred = eval(model_noBN, device, test_loader, evaluator)
print(ypred)

torch.save(model_noBN, 'gin_ep1_noBN_dim100.pt')
# Out:
# Evaluating...
# Batch(batch=[19], edge_attr=[40, 3], edge_index=[2, 40], x=[19, 9], y=[1, 1])
# [[-3.6961656]]
# Batch(batch=[19], edge_attr=[40, 3], edge_index=[2, 40], x=[19, 9], y=[1, 1])
# [[-3.6961656]]

# %%
import json
from struct import *
import struct
import torch
from torch_geometric.data import DataLoader
import torch.optim as optim
import torch.nn.functional as F
from gnn import GNN, GNN_noBN
from sklearn.metrics import roc_auc_score

from tqdm import tqdm
import argparse
import time
import numpy as np

########### collecting weights #######################

model = torch.load('gin_ep1_noBN_dim100.pt')

# weights_dict = {}
# weights_data = []
# offset = 0
# for key in model.state_dict():
#     print(key)
#     #print(model.state_dict()[key].shape)
#     #print(model.state_dict()[key].view(-1).numpy().shape)

#     weights_dict[key] = {}
#     weights_dict[key]['shape'] = list(model.state_dict()[key].shape)
#     weights_dict[key]['key'] = key
#     weights_dict[key]['offset'] = offset
#     data = list(model.state_dict()[key].view(-1).numpy())
#     data_length = len(data)
#     weights_dict[key]['length'] = data_length
#     offset += data_length
#     weights_data += data

# f = open('gin_ep1_noBN.weights.dict.json', 'w')
# json.dump(weights_dict, f)
# f.close()

# f = open('gin_ep1_noBN.weights.data.bin', 'wb')
# packed = struct.pack('f'*len(weights_data), *weights_data)
# f.write(packed)
# f.close()

### pack MLP weights
MLP_weights_0_1 = model.state_dict()['gnn_node_noBN.convs.0.mlp.0.weight'].numpy()
MLP_weights_1_1 = model.state_dict()['gnn_node_noBN.convs.1.mlp.0.weight'].numpy()
MLP_weights_2_1 = model.state_dict()['gnn_node_noBN.convs.2.mlp.0.weight'].numpy()
MLP_weights_3_1 = model.state_dict()['gnn_node_noBN.convs.3.mlp.0.weight'].numpy()
MLP_weights_4_1 = model.state_dict()['gnn_node_noBN.convs.4.mlp.0.weight'].numpy()
MLP_1_weights_all = torch.tensor([MLP_weights_0_1, MLP_weights_1_1, MLP_weights_2_1, MLP_weights_3_1, MLP_weights_4_1])
print(MLP_1_weights_all.shape)

MLP_weights_0_2 = model.state_dict()['gnn_node_noBN.convs.0.mlp.2.weight'].numpy()
MLP_weights_1_2 = model.state_dict()['gnn_node_noBN.convs.1.mlp.2.weight'].numpy()
MLP_weights_2_2 = model.state_dict()['gnn_node_noBN.convs.2.mlp.2.weight'].numpy()
MLP_weights_3_2 = model.state_dict()['gnn_node_noBN.convs.3.mlp.2.weight'].numpy()
MLP_weights_4_2 = model.state_dict()['gnn_node_noBN.convs.4.mlp.2.weight'].numpy()
MLP_2_weights_all = torch.tensor([MLP_weights_0_2, MLP_weights_1_2, MLP_weights_2_2, MLP_weights_3_2, MLP_weights_4_2])
print(MLP_2_weights_all.shape)

MLP_bias_0_1 = model.state_dict()['gnn_node_noBN.convs.0.mlp.0.bias'].numpy()
MLP_bias_1_1 = model.state_dict()['gnn_node_noBN.convs.1.mlp.0.bias'].numpy()
MLP_bias_2_1 = model.state_dict()['gnn_node_noBN.convs.2.mlp.0.bias'].numpy()
MLP_bias_3_1 = model.state_dict()['gnn_node_noBN.convs.3.mlp.0.bias'].numpy()
MLP_bias_4_1 = model.state_dict()['gnn_node_noBN.convs.4.mlp.0.bias'].numpy()
MLP_1_bias_all = torch.tensor([MLP_bias_0_1, MLP_bias_1_1, MLP_bias_2_1, MLP_bias_3_1, MLP_bias_4_1])
print(MLP_1_bias_all.shape)

MLP_bias_0_2 = model.state_dict()['gnn_node_noBN.convs.0.mlp.2.bias'].numpy()
MLP_bias_1_2 = model.state_dict()['gnn_node_noBN.convs.1.mlp.2.bias'].numpy()
MLP_bias_2_2 = model.state_dict()['gnn_node_noBN.convs.2.mlp.2.bias'].numpy()
MLP_bias_3_2 = model.state_dict()['gnn_node_noBN.convs.3.mlp.2.bias'].numpy()
MLP_bias_4_2 = model.state_dict()['gnn_node_noBN.convs.4.mlp.2.bias'].numpy()
MLP_2_bias_all = torch.tensor([MLP_bias_0_2, MLP_bias_1_2, MLP_bias_2_2, MLP_bias_3_2, MLP_bias_4_2])
print(MLP_2_bias_all.shape)

data = list(MLP_1_weights_all.view(-1).numpy())
f = open('gin_ep1_mlp_1_weights.bin', 'wb')
packed = struct.pack('f'*len(data), *data)
f.write(packed)
f.close()

data = list(MLP_1_bias_all.view(-1).numpy())
f = open('gin_ep1_mlp_1_bias.bin', 'wb')
packed = struct.pack('f'*len(data), *data)
f.write(packed)
f.close()


data = list(MLP_2_weights_all.view(-1).numpy())
f = open('gin_ep1_mlp_2_weights.bin', 'wb')
packed = struct.pack('f'*len(data), *data)
f.write(packed)
f.close()


data = list(MLP_2_bias_all.view(-1).numpy())
f = open('gin_ep1_mlp_2_bias.bin', 'wb')
packed = struct.pack('f'*len(data), *data)
f.write(packed)
f.close()


### merge all the embedding tables into one
### Ahhh this is cumbersome
nd_emb_0 = model.state_dict()['gnn_node_noBN.atom_encoder.atom_embedding_list.0.weight']
nd_emb_1 = model.state_dict()['gnn_node_noBN.atom_encoder.atom_embedding_list.1.weight']
nd_emb_2 = model.state_dict()['gnn_node_noBN.atom_encoder.atom_embedding_list.2.weight']
nd_emb_3 = model.state_dict()['gnn_node_noBN.atom_encoder.atom_embedding_list.3.weight']
nd_emb_4 = model.state_dict()['gnn_node_noBN.atom_encoder.atom_embedding_list.4.weight']
nd_emb_5 = model.state_dict()['gnn_node_noBN.atom_encoder.atom_embedding_list.5.weight']
nd_emb_6 = model.state_dict()['gnn_node_noBN.atom_encoder.atom_embedding_list.6.weight']
nd_emb_7 = model.state_dict()['gnn_node_noBN.atom_encoder.atom_embedding_list.7.weight']
nd_emb_8 = model.state_dict()['gnn_node_noBN.atom_encoder.atom_embedding_list.8.weight']

print(nd_emb_0.shape)
print(nd_emb_1.shape)
print(nd_emb_2.shape)
print(nd_emb_3.shape)
print(nd_emb_4.shape)
print(nd_emb_5.shape)
print(nd_emb_6.shape)
print(nd_emb_7.shape)
print(nd_emb_8.shape)

nd_all = torch.cat((nd_emb_0, nd_emb_1, nd_emb_2, nd_emb_3, nd_emb_4, nd_emb_5, nd_emb_6, nd_emb_7, nd_emb_8), dim=0)
print(nd_all.shape)


data = list(nd_all.view(-1).numpy())
f = open('gin_ep1_nd_embed.bin', 'wb')
packed = struct.pack('f'*len(data), *data)
f.write(packed)
f.close()


ed_emb_0_0 = model.state_dict()['gnn_node_noBN.convs.0.bond_encoder.bond_embedding_list.0.weight']
ed_emb_0_1 = model.state_dict()['gnn_node_noBN.convs.0.bond_encoder.bond_embedding_list.1.weight']
ed_emb_0_2 = model.state_dict()['gnn_node_noBN.convs.0.bond_encoder.bond_embedding_list.2.weight']

print(ed_emb_0_0.shape)
print(ed_emb_0_1.shape)
print(ed_emb_0_2.shape)

ed_emb_1_0 = model.state_dict()['gnn_node_noBN.convs.1.bond_encoder.bond_embedding_list.0.weight']
ed_emb_1_1 = model.state_dict()['gnn_node_noBN.convs.1.bond_encoder.bond_embedding_list.1.weight']
ed_emb_1_2 = model.state_dict()['gnn_node_noBN.convs.1.bond_encoder.bond_embedding_list.2.weight']

ed_emb_2_0 = model.state_dict()['gnn_node_noBN.convs.2.bond_encoder.bond_embedding_list.0.weight']
ed_emb_2_1 = model.state_dict()['gnn_node_noBN.convs.2.bond_encoder.bond_embedding_list.1.weight']
ed_emb_2_2 = model.state_dict()['gnn_node_noBN.convs.2.bond_encoder.bond_embedding_list.2.weight']

ed_emb_3_0 = model.state_dict()['gnn_node_noBN.convs.3.bond_encoder.bond_embedding_list.0.weight'] 
ed_emb_3_1 = model.state_dict()['gnn_node_noBN.convs.3.bond_encoder.bond_embedding_list.1.weight']
ed_emb_3_2 = model.state_dict()['gnn_node_noBN.convs.3.bond_encoder.bond_embedding_list.2.weight']

ed_emb_4_0 = model.state_dict()['gnn_node_noBN.convs.4.bond_encoder.bond_embedding_list.0.weight']
ed_emb_4_1 = model.state_dict()['gnn_node_noBN.convs.4.bond_encoder.bond_embedding_list.1.weight']
ed_emb_4_2 = model.state_dict()['gnn_node_noBN.convs.4.bond_encoder.bond_embedding_list.2.weight']

ed_all = torch.cat((ed_emb_0_0, ed_emb_0_1, ed_emb_0_2, \
                    ed_emb_1_0, ed_emb_1_1, ed_emb_1_2, \
                    ed_emb_2_0, ed_emb_2_1, ed_emb_2_2, \
                    ed_emb_3_0, ed_emb_3_1, ed_emb_3_2, \
                    ed_emb_4_0, ed_emb_4_1, ed_emb_4_2), dim=0)

print(ed_all.shape)
data = list(ed_all.view(-1).numpy())
f = open('gin_ep1_ed_embed.bin', 'wb')
packed = struct.pack('f'*len(data), *data)
f.write(packed)
f.close()


for key in model.state_dict():
    if 'eps' in key:
        print(model.state_dict()[key].numpy(), key)


eps0 = model.state_dict()['gnn_node_noBN.convs.0.eps']
eps1 = model.state_dict()['gnn_node_noBN.convs.1.eps']
eps2 = model.state_dict()['gnn_node_noBN.convs.2.eps']
eps3 = model.state_dict()['gnn_node_noBN.convs.3.eps']
eps4 = model.state_dict()['gnn_node_noBN.convs.4.eps']
eps_all = torch.tensor([eps0, eps1, eps2, eps3, eps4])
data = list(eps_all.view(-1).numpy())
f = open('gin_ep1_eps.bin', 'wb')
packed = struct.pack('f'*len(data), *data)
f.write(packed)
f.close()



pred_w = model.state_dict()['graph_pred_linear.weight']
pred_b = model.state_dict()['graph_pred_linear.bias']
print(pred_w.shape, pred_b.shape)

data = list(pred_w.view(-1).numpy())
f = open('gin_ep1_pred_weights.bin', 'wb')
packed = struct.pack('f'*len(data), *data)
f.write(packed)
f.close()


data = list(pred_b.view(-1).numpy())
f = open('gin_ep1_pred_bias.bin', 'wb')
packed = struct.pack('f'*len(data), *data)
f.write(packed)
f.close()
# Out:
# torch.Size([5, 600, 300])
# torch.Size([5, 300, 600])
# torch.Size([5, 600])
# torch.Size([5, 300])
# torch.Size([119, 300])
# torch.Size([4, 300])
# torch.Size([12, 300])
# torch.Size([12, 300])
# torch.Size([10, 300])
# torch.Size([6, 300])
# torch.Size([6, 300])
# torch.Size([2, 300])
# torch.Size([2, 300])
# torch.Size([173, 300])
# torch.Size([5, 300])
# torch.Size([6, 300])
# torch.Size([2, 300])
# torch.Size([65, 300])
# [-0.08026089] gnn_node_noBN.convs.0.eps
# [-0.0451563] gnn_node_noBN.convs.1.eps
# [-0.0093365] gnn_node_noBN.convs.2.eps
# [0.03119815] gnn_node_noBN.convs.3.eps
# [0.07610212] gnn_node_noBN.convs.4.eps
# torch.Size([1, 300]) torch.Size([1])
